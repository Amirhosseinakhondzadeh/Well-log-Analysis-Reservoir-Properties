# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import lasio
from dlisio import dlis
pd.set_option('display.max_rows', 500)


f, *tail = dlis.load("/Users/amirhosseinakhondzadeh/Data/Forge 16A 78-32 TBEI image log with calibrated caliper arms_DLIS.DLIS")
print(f)
print(tail)

print(f.describe())


"""* ORIGIN *"""
""" The first set of metadata we will look at is the origin. This provides information about the source of the data
 within the file. Occasionally, data may originate from multiple sources so we need to account for this by
  unpacking the origins into two variables. We can always check if there is other origin information by printing
   the length of the list. """

origin, *origin_tail = f.origins
print(len(origin_tail))
print(origin.describe())

"""* Frames *"""
""" Frames within a DLIS file can represent different logging passes or different stages of data, such as raw well log
 measurements to petrophysical interpretations or processed data. Each frame has a number of properties. 
 The example code below prints out the properties in an easy-to-read format. """

for frame in f.frames:

    # Search through the channels for the index and obtain the units
    for channel in frame.channels:
        if channel.name == frame.index:
            depth_units = channel.units

    print(f'Frame Name: \t\t {frame.name}')
    print(f'Index Type: \t\t {frame.index_type}')
    print(f'Depth Interval: \t {frame.index_min} - {frame.index_max} {depth_units}')
    print(f'Depth Spacing: \t\t {frame.spacing} {depth_units}')
    print(f'Direction: \t\t {frame.direction}')
    print(f'Num of Channels: \t {len(frame.channels)}')
    print(f'Channel Names: \t\t {str(frame.channels)}')
    print('\n\n')


"""* Parameters within the DLIS File *"""
""" As seen earlier, we have a number of objects associated with the DLIS file. To make them easier to read
 we can create a short function that creates a pandas dataframe containing the parameters. """


def summary_dataframe(object, **kwargs):
    # Create an empty dataframe
    df = pd.DataFrame()
    # Iterate over each of the keyword arguments
    for i, (key, value) in enumerate(kwargs.items()):
        list_of_values = []
        # Iterate over each parameter and get the relevant key
        for item in object:
            # Account for any missing values.
            try:
                x = getattr(item, key)
                list_of_values.append(x)
            except:
                list_of_values.append('')
                continue
        # Add a new column to our data frame
        df[value] = list_of_values
    # Sort the dataframe by column 1 and return it
    return df.sort_values(df.columns[0])


param_df = summary_dataframe(f.parameters, name='Name', long_name='Long Name', values='Value')

# Hiding people's names that may be in parameters.
# These two lines can be commented out to show them
mask = param_df['Name'].isin(['R8', 'RR1', 'WITN', 'ENGI'])
param_df = param_df[~mask]

param_df
# Out:
# LogicalFile(ConPr_R18_L001Up_TBEI_TMG_TBCCL)
# []
# ------------
# Logical File
# ------------
# Description : LogicalFile(ConPr_R18_L001Up_TBEI_TMG_TBCCL)
# Frames      : 3
# Channels    : 226
#
# Known objects
# --
# ORIGIN                  : 1
# PROCESS                 : 4
# CALIBRATION-MEASUREMENT : 20
# CHANNEL                 : 226
# CALIBRATION-COEFFICIENT : 37
# EQUIPMENT               : 18
# PARAMETER               : 439
# FILE-HEADER             : 1
# TOOL                    : 1
# FRAME                   : 3
# CALIBRATION             : 5
#
# Unknown objects
# --
# 440-FILE                    : 1
# 440-HZVERSIONINFO           : 1
# 440-PASS                    : 1
# 440-CALIBRATION-COEFFICIENT : 37
# 440-OP-TOOL                 : 1
# 440-CHANNEL                 : 223
# 440-LIS-INPU                : 223
#
#
# 0
# ------
# Origin
# ------
# name   : LAP-93ED06FF-CDB6-4EEF-BE24-93FCC52D2D04
# origin : 54
# copy   : 0
#
# Logical file ID          : ConPr_R18_L001Up_TBEI_TMG_TBCCL
# File set name and number : UNIVERSITYUTAH / 1056964608
# File number and type     : 1 / PRODUCER
#
# Field                   : Wildcat
# Well (id/name)          :  / Forge 16A(78)-32
# Produced by (code/name) : 440 / Schlumberger
# Produced for            : University of Utah
# Order number            : UniversityUtah
# Run number              : 18
# Descent number          : 0
# Created                 : 2021-01-03 20:04:14.166000
#
# Created by              : HZ-OP:Wireline, (version: 11.0.209095.3100)
# Other programs/services : TENSION_DEVICE:Tension Device
#                           WAFE:WAFE type
#                           DEPTH_DEVICE:Depth Measuring Device
#                           LOGGING_CABLE:Logging Cable
#                           TMG-A:ThruBit Telemetry Memory Gamma A - 2 1/8in - 10
#                           pin     TBEI-A:ThruBit WBM Imager Tool version A
#                           (TBEI-AA or TBEI-XA) TBCCL-A:THRUBIT CASING COLLAR
#                           LOCATOR TOOL version A
#
#
# Frame Name: 		 1B
# Index Type: 		 BOREHOLE-DEPTH
# Depth Interval: 	 176160.0 - 1307041.0 0.1 in
# Depth Spacing: 		 -1.0 0.1 in
# Direction: 		 DECREASING
# Num of Channels: 	 63
# Channel Names: 		 [Channel(TDEP), Channel(BA2_Q), Channel(BH2_P), Channel(BF2_P), Channel(BF1_P), Channel(BE1_Q), Channel(BD3_Q), Channel(BF3_P), Channel(BD1_P), Channel(TBEI_RBM), Channel(TBEI_AZ_TEMP), Channel(BH3_Q), Channel(TBEI3_IMAGE), Channel(TBEI_AX_TEMP), Channel(BH3_P), Channel(BF1_Q), Channel(BD2_Q), Channel(TBEI_DEVI), Channel(BC1_Q), Channel(BE1_P), Channel(BD1_Q), Channel(BB3_P), Channel(BG3_Q), Channel(BD3_P), Channel(BE3_P), Channel(TBEI_AX), Channel(TBEI_ARAW), Channel(BA3_Q), Channel(BC2_Q), Channel(BG2_P), Channel(BB3_Q), Channel(BB1_P), Channel(BG2_Q), Channel(TBEI_AY), Channel(BG1_Q), Channel(BA1_P), Channel(TBEI_AZ), Channel(BG1_P), Channel(BF3_Q), Channel(TBEI_ANOR), Channel(BB2_Q), Channel(BH2_Q), Channel(BC3_Q), Channel(BD2_P), Channel(BH1_P), Channel(BA1_Q), Channel(BB2_P), Channel(BG3_P), Channel(TBEI_RB), Channel(BC3_P), Channel(BE2_Q), Channel(BA2_P), Channel(BE3_Q), Channel(BB1_Q), Channel(BC1_P), Channel(BH1_Q), Channel(TBEI_DEVIM), Channel(TBEI_AY_TEMP), Channel(BC2_P), Channel(BE2_P), Channel(BF2_Q), Channel(BA3_P), Channel(TBEI_TDEP)]
#
#
#
# Frame Name: 		 60B
# Index Type: 		 BOREHOLE-DEPTH
# Depth Interval: 	 170580.0 - 1307040.0 0.1 in
# Depth Spacing: 		 -60.0 0.1 in
# Direction: 		 DECREASING
# Num of Channels: 	 159
# Channel Names: 		 [Channel(TDEP), Channel(C1HP_13), Channel(DEVI), Channel(ACPU_1), Channel(C2_TEMP), Channel(C2_24), Channel(RAX), Channel(ATMP_1), Channel(I5VD), Channel(TENS), Channel(RC2_24), Channel(RB), Channel(RC1_24), Channel(C3HP_13), Channel(C3_24), Channel(C1_TEMP), Channel(IHV_RM), Channel(CECC), Channel(TDSP), Channel(APGA1_2), Channel(E60V), Channel(VSEC), Channel(ITMP), Channel(C2CC), Channel(DEPTH), Channel(AREA), Channel(EV5D), Channel(C2RC), Channel(CSYN), Channel(RGR_TMG), Channel(RC1_13), Channel(A5VM_3), Channel(APGA2_1), Channel(AX), Channel(CMEC), Channel(AZ), Channel(EMSTS), Channel(ACPU_3), Channel(APGA2_3), Channel(C2HP_13), Channel(RAY), Channel(AREF_1), Channel(APGA1_1), Channel(ETXI), Channel(FCD_RM), Channel(EPRI), Channel(WTEP_TMG), Channel(AREF_2), Channel(GTEM_RM), Channel(ABST_3), Channel(C3HP_24), Channel(CMDC), Channel(IGND), Channel(ECGR_TMG), Channel(S5VD_3), Channel(ATMP_2), Channel(RC3_24), Channel(AY), Channel(CMCC), Channel(TOOL_STATUS), Channel(APGA3_3), Channel(C1CC), Channel(HDAR_RM), Channel(CMAC), Channel(BFHI_RM), Channel(CVEL), Channel(APGA3_4), Channel(RAZ), Channel(CMRC), Channel(APGA1_4), Channel(C3CC), Channel(ABST_2), Channel(RC2_13), Channel(C3CC_R), Channel(TVD), Channel(A5VP_2), Channel(E3VA), Channel(CECC_R), Channel(CINRC), Channel(APGA3_1), Channel(C1RC), Channel(EDAC), Channel(AFST_3), Channel(S5VD_1), Channel(C2_13), Channel(A5VP_1), Channel(E13M), Channel(HV_TMG), Channel(C3_13), Channel(GR_TMG), Channel(CINCC_R), Channel(S5VD_2), Channel(A5VM_2), Channel(C3_TEMP), Channel(AZIM), Channel(EBTP), Channel(CMCC_R), Channel(GHD_RM), Channel(C4RC), Channel(INCL), Channel(C1_24), Channel(I13P), Channel(AFST_2), Channel(BHPR_RM), Channel(ED), Channel(BS_RM), Channel(ICV_RM), Channel(C4CC_R), Channel(STIT), Channel(C4CC), Channel(ETXV), Channel(C1HP_24), Channel(C2HP_24), Channel(C3RC), Channel(IDWD), Channel(A5VP_3), Channel(CINCC), Channel(APPR), Channel(CERC), Channel(APGA1_3), Channel(APGA2_4), Channel(FF_RM), Channel(ATMP_3), Channel(APGA3_2), Channel(A5VM_1), Channel(E13P), Channel(AREF_3), Channel(CCPU), Channel(I13M), Channel(ROAZ), Channel(EDTB), Channel(C1CC_R), Channel(ACPU_2), Channel(CS), Channel(ISTS), Channel(DCAL_RM), Channel(CMDC_R), Channel(I5VA), Channel(DLS), Channel(CESP), Channel(GHID_RM), Channel(TVDSS), Channel(RC3_13), Channel(CBTP), Channel(ICPU), Channel(C2CC_R), Channel(ABST_1), Channel(EPSP), Channel(C5VD), Channel(CSTS), Channel(TB_SDT_DIFF), Channel(BHRM_RM), Channel(AFST_1), Channel(ND), Channel(APGA2_2), Channel(C1_13), Channel(AREA_RM), Channel(AREA), Channel(MD)]
#
#
#
# Frame Name: 		 10B
# Index Type: 		 BOREHOLE-DEPTH
# Depth Interval: 	 180000.0 - 1307040.0 0.1 in
# Depth Spacing: 		 -10.0 0.1 in
# Direction: 		 DECREASING
# Num of Channels: 	 4
# Channel Names: 		 [Channel(TDEP), Channel(CS), Channel(CVEL), Channel(TENS)]
# /Users/amirhosseinakhondzadeh/opt/anaconda3/lib/python3.9/site-packages/dlisio/dlis/parameter.py:137: UnicodeWarning: unable to decode string b'112\xb0 53\' 47.066" W'
#   values = self.attic['VALUES'].value
# /Users/amirhosseinakhondzadeh/opt/anaconda3/lib/python3.9/site-packages/dlisio/dlis/parameter.py:137: UnicodeWarning: unable to decode string b'38\xb0 30\' 14.447" N'
#   values = self.attic['VALUES'].value
#                                   Name  \
# 136                                  A
# 250                         ACTIVESERV
# 116                        ACTIVESERV1
# 157                        ACTIVESERV2
# 258                        ACTIVESERV3
# 287                            AC_TRIM
# 149                       ADC_GAIN_OPT
# 64                            ALT_PDAT
# 145                                AMD
# 56                                 APD
# 240                               APIN
# 72                                APRE
# 346                               ATEM
# 219                  AUTO_SEND_COMMAND
# 106                            AU_TRIM
# 271                          AZ_SELECT
# 95                                 BAP
# 168                               BARI
# 180                               BASI
# 162                                 BG
# 134                               BHAL
# 259                                BHK
# 199                                BHS
# 63                                 BHT
# 378                             BHT_RM
# 181                                BLI
# 226                                 BO
# 97                                 BPP
# 208                                BPT
# 315                                 BS
# 158                               BSAL
# 363                            BSAL_RM
# 316                               BSDF
# 317                               BSDT
# 89                                BSSO
# 143                                 BW
# 318                               CADT
# 435                     CALI_CABLE_TYP
# 424                          CALI_DATE
# 423                          CALI_DATE
# 426                     CALI_SERIALNUM
# 425                     CALI_SERIALNUM
# 319                               CASG
# 18                       CASING_LAYOUT
# 192                               CASN
# 320                               CBDR
# 321                               CBLO
# 213                               CCLG
# 322                                CDF
# 323                               CDIA
# 123                               CDTS
# 324                               CGRD
# 170                               CLAB
# 381                   CMR_FORM_H2O_SAL
# 85                                  CN
# 176                                CN1
# 179                               CONT
# 172                             CONTYP
# 67                       COORDSYS_NAME
# 239                               COUN
# 325                               CSDE
# 326                               CSID
# 327                               CSIZ
# 294                               CSLH
# 114                               CTOT
# 328                               CWEI
# 329                               CYST
# 309                               DATE
# 282                               DATF
# 193                               DATT
# 310                                DCS
# 140                            DC_MODE
# 197                            DC_TRIM
# 20                           DELT_LOCB
# 74                           DELT_LOCG
# 58                           DELT_MDIP
# 59                      DELT_USER_LOCB
# 33                      DELT_USER_LOCG
# 65                      DELT_USER_MDIP
# 126                            DEPREM1
# 98                             DEPREM2
# 251                            DEPREM3
# 268                            DEPREM4
# 117                            DEPREM5
# 190                            DEPREM6
# 214                     DEPTH_SYS_TYPE
# 241                                DFD
# 264                               DFES
# 187                                DFL
# 115                               DFPH
# 387                                DFT
# 256                               DFTS
# 159                       DFT_CATEGORY
# 183                                DFV
# 369                               DFVL
# 96                                DHGS
# 1                      DIAM_LARGE_RING
# 2                      DIAM_SMALL_RING
# 281                        DIP_AZIMUTH
# 133                           DISTRICT
# 311                               DLAB
# 38                        DMAG_CORR_ON
# 68                         DMAG_CUTOFF
# 394                                DMF
# 69                            DNI_DATE
# 163                               DOWR
# 132                               DSSN
# 135                                DTF
# 189                                DTM
# 221                               DTMD
# 385                              DTMUD
# 382                           DTMUD_RM
# 32                                 EAE
# 395                                ECF
# 396                                EDF
# 77                                 EDI
# 397                                EGL
# 398                                EKB
# 28                                 ELZ
# 101                           EMEX_LVL
# 131                        EMEX_PWRLIM
# 194                            ENABLED
# 195                            ENABLED
# 196                            ENABLED
# 55                                 EPD
# 436                     EP_DDEQUIP_TYP
# 433                     EP_LCEQUIP_TYP
# 427                     EP_TDEQUIP_TYP
# 13                                ETIP
# 253                 EWAFE_BASELINE_VER
# 108                 EWAFE_DL_AMPLITUDE
# 166                    EWAFE_DL_FILTER
# 161               EWAFE_DL_PULSE_WIDTH
# 284                      EWAFE_SYS_VER
# 231             EWAFE_UL_FILTER_COEFF0
# 165                 EWAFE_UL_THRESHOLD
# 139                                FCD
# 252                                 FD
# 386                               FEXP
# 113                                FFV
# 130                                 FL
# 244                                FL1
# 174                                FL2
# 347                               FLDE
# 34                                FLEV
# 201                                 FN
# 359                               FNUM
# 334                               FPHI
# 335                               FPHI
# 238                               FSAL
# 355                               FVEL
# 352                        GAS_DENSITY
# 336                            GCSE_RM
# 337                            GCSE_RM
# 230                                GDD
# 364                           GDD_SPRI
# 66                                GDEV
# 46                        GEOMAG_MODEL
# 80                    GEOMAG_YEAR_INFO
# 279                               GGRA
# 142                               GGRD
# 31                                GMLD
# 52                                GMLG
# 26                                GMLH
# 261                                GOR
# 383                           GOR_SPRI
# 120       GPIT_CABLE_CONFIDENCE_FACTOR
# 128                GPIT_RECOVERY_SPEED
# 289  GPIT_STICKING_DETECTION_THRESHOLD
# 356                               GRAD
# 53                                GRDC
# 338                            GRSE_RM
# 339                            GRSE_RM
# 341                            GTSE_RM
# 340                            GTSE_RM
# 263                               GVIS
# 152                               HDAT
# 421                               HID1
# 422                               HID2
# 420                               HIDE
# 218                               HIFF
# 354                   HILT_GAS_DENSITY
# 343                               HVCS
# 342                               HVCS
# 216                                IBG
# 36                        IGN_DL_FTSPE
# 17                        IGN_DL_STDEP
# 48                        IGN_DL_STINT
# 49                              IGN_SL
# 39                       IGN_SL_STTIME
# 119                               IHVC
# 351                               IHVS
# 186                        IS_TND_MODE
# 0                         JIG_STRENGTH
# 220                              JOBID
# 374                               KPER
# 37                                LATD
# 25                                LATI
# 260                                LCC
# 148                               LCC1
# 434                                LCL
# 297                               LCSN
# 27                       LC_DEFINITION
# 94                                LLAB
# 23                                 LMF
# 169                               LNAM
# 333                               LOC1
# 75                                LOCG
# 227                             LOGSEQ
# 91                              LOGTYP
# 86                      LOG_START_TIME
# 127                      LOG_STOP_TIME
# 62                                LOND
# 12                                LONG
# 236                               LSRV
# 177                                LUL
# 93                                 LUN
# 102                                  M
# 22                      MANL_GRID_CONV
# 388                               MATR
# 185                      MAX_LOG_SPEED
# 274                               MCSS
# 137                               MCST
# 9                                 MDEC
# 10                                MDEC
# 389                               MDEN
# 47                        MERGE_DL_PAS
# 211                   MESSAGES_TO_SKIP
# 212                   MESSAGES_TO_SKIP
# 15                                MFIN
# 286                               MFSS
# 118                               MFST
# 105                                MHD
# 44                                MINC
# 380                               MRES
# 11                                 MRT
# 14                                MRT1
# 73                                MRT2
# 16                                MRT3
# 87                                 MSS
# 81                                 MST
# 349                             MST_RM
# 265                               MVIS
# 368                                 MW
# 344                              MW_RM
# 90                                   N
# 224                               NATI
# 8                            NORTH_REF
# 390                                OBM
# 156                                ODD
# 376                           ODD_SPRI
# 262                               ODEN
# 204              OFFSHORE_BLOCK_NUMBER
# 112                               OGRA
# 348                          OGRA_SPRI
# 375                                OMR
# 350                               OMRX
# 245                               OPER
# 415                                OS1
# 416                                OS2
# 417                                OS3
# 418                                OS4
# 419                                OS5
# 40                        OVERIDE_LOCB
# 42                        OVERIDE_LOCG
# 4                       OVERIDE_MAGDEC
# 57                      OVERIDE_MAGDIP
# 144                               OVIS
# 54                       PAUSE_TIMEINT
# 164                            PCIDDRL
# 121                            PCODDRL
# 82                                PDAT
# 167                                PHI
# 141                       PHONE_NUMBER
# 205                            PLODDRL
# 366                               PMUD
# 312                               PVER
# 235                                 R1
# 100                                R10
# 103                                R11
# 269                                R12
# 267                                R13
# 173                                R14
# 243                                R15
# 223                                R16
# 247                                R17
# 206                                 R2
# 229                                 R3
# 200                                 R4
# 285                                 R5
# 184                                 R6
# 232                                 R7
# 191                                 R9
# 272                               RANG
# 154                          RB_OFFSET
# 293                     REQPERFOINTRVL
# 360                               RHOF
# 151                             RIGDST
# 207                               RIGN
# 175                             RIGTYP
# 171                          RIGTZBIAS
# 225                               RLAB
# 249                               RLDT
# 266                               RLNM
# 215                               RLRN
# 70                                 RMB
# 60                                RMCB
# 202                               RMCS
# 30                                RMFB
# 182                               RMFS
# 79                                 RMS
# 357                             RMS_RM
# 358                               RMUD
# 370                               RMUX
# 234                              ROMFS
# 308                               RR10
# 306                                RR2
# 304                                RR3
# 305                                RR4
# 307                                RR5
# 303                                RR6
# 300                                RR7
# 299                                RR8
# 301                                RR9
# 365                               RTST
# 384                            RT_BSAL
# 222                               RULB
# 153                               RULS
# 209                                RUN
# 391                               RUPI
# 147                                 RW
# 99                                 RWF
# 45                                 RWS
# 50                         SAG_CORR_ON
# 203                              SCORR
# 393                          SEABDEPTH
# 237                          SEC1_GAIN
# 292                          SEC2_GAIN
# 242                          SEC3_GAIN
# 92                                SECT
# 362                          SEXP_HILT
# 248                               SFTY
# 283                               SGOR
# 5                                  SHT
# 361                             SHT_RM
# 150                     SIMULATED_DATA
# 122                               SLAB
# 21                      SLIP_DOWN_MOVE
# 129                                SON
# 295                                SPF
# 392                               SPFS
# 138                          SPUD_DATE
# 275                               STAT
# 257                              STDLC
# 371                               STEM
# 104                               STKT
# 24                            TBEI_FIG
# 19                        TBEI_HIST_EQ
# 3                        TBEI_IMG_COND
# 35                         TBEI_ROTATE
# 71                      TBEI_ROT_BSKIP
# 51                      TBEI_ROT_BYPAD
# 84                        TBEI_ROT_MIN
# 83                        TBEI_ROT_THR
# 29                        TBEI_ROT_WIN
# 6                        TBEI_ROT_ZANG
# 78                      TBEI_ROT_ZONED
# 254                               TBGD
# 313                                TCS
# 61                                  TD
# 330                                TDD
# 331                                TDL
# 428                       TD_CALI_GAIN
# 432                     TD_CALI_OFFSET
# 429                   TD_CALI_PEAK_ERR
# 431                        TD_CALI_PTS
# 430                        TD_CALI_RMS
# 345                              TD_RM
# 288                 TD_TOLERANCE_LEVEL
# 188                   TEL_DL_AMPLITUDE
# 146                 TEL_DL_PULSE_WIDTH
# 291               TEL_UL_FILTER_COEFF0
# 107               TEL_UL_FILTER_COEFF1
# 255               TEL_UL_FILTER_COEFF2
# 124               TEL_UL_FILTER_COEFF3
# 290                   TEL_UL_THRESHOLD
# 353                        TET_SHOT_VT
# 332                               THNO
# 314                               TLAB
# 273                                TLI
# 110                              TLLAB
# 298                         TMG_BHC_OP
# 296                              TNDSN
# 210                              TOOLS
# 399                         TOOL_MAP_1
# 408                        TOOL_MAP_10
# 409                        TOOL_MAP_11
# 410                        TOOL_MAP_12
# 411                        TOOL_MAP_13
# 412                        TOOL_MAP_14
# 413                        TOOL_MAP_15
# 414                        TOOL_MAP_16
# 400                         TOOL_MAP_2
# 401                         TOOL_MAP_3
# 402                         TOOL_MAP_4
# 403                         TOOL_MAP_5
# 404                         TOOL_MAP_6
# 405                         TOOL_MAP_7
# 406                         TOOL_MAP_8
# 407                         TOOL_MAP_9
# 7                                 TOTC
# 278                               TOWN
# 160                               TPOS
# 246                               TREF
# 76                                 TWS
# 373                             TWS_RM
# 155                               UWID
# 43                                VHOL
# 270                       VILL_VDCLRAT
# 377                           VIS_OBMF
# 111                       VKAO_VDCLRAT
# 88                        VMON_VDCLRAT
# 125                                WDD
# 41                                WDEP
# 437                        WHEEL_CORR1
# 438                        WHEEL_CORR2
# 228                      WIRELOCK_INFO
# 372                               WMUC
# 379                               WMUD
# 276                                 WN
# 198                               WSAL
# 367                          WSAL_SPRI
# 217                               WVIS
# 277                               ZMUD
# 233                               ZRCS
#
#                                              Long Name  \
# 136  Constant A of the Archie Formation Factor - Po...
# 250                             Primary ACTive Service
# 116                        Additional ACTive Service 1
# 157                        Additional ACTive Service 2
# 258                        Additional ACTive Service 3
# 287                                 AC Main Cable Trim
# 149                               WITM ADC Gain Option
# 64   Name of Alternate Permanent Datum (for PDAT = ...
# 145                       Azimuth of Maximum Deviation
# 56   Elevation of Depth Reference (LMF) Above Perma...
# 240                                    API Well Number
# 72                                Atmospheric Pressure
# 346                                Ambient Temperature
# 219             Send Automatic Startup Commands Option
# 106                                  AC AUX Cable Trim
# 271  Z-Axis Acceleration Channel Selection for Real...
# 95    Elevation of the cellar base, for on-shore wells
# 168                           Barite Mud Presence Flag
# 180  Name of the sedimentary basin in which the wel...
# 162                    Gas Formation Volume Factor, Bg
# 134                   Borehole Aluminum Weight Percent
# 259             Drilling Fluid Potassium Concentration
# 199               Borehole Status (Open or Cased Hole)
# 63                             Bottom Hole Temperature
# 378                       Bottom Hole Temperature (RM)
# 181                                Bottom Log Interval
# 226                    Oil Formation Volume Factor, Bo
# 97                               Bubble Point Pressure
# 208                           Bubble Point Temperature
# 315                                           Bit Size
# 158                                  Borehole Salinity
# 363  Borehole Salinity (NaCl-equivalent concentrati...
# 316                                Bit Size Depth From
# 317                                  Bit Size Depth To
# 89                    Source of Borehole Salinity Data
# 143                  Water Formation Volume Factor, Bw
# 318                                    Casing Depth To
# 435                             Calibration Cable Type
# 424                                   Calibration Date
# 423                                   Calibration Date
# 426                           Calibrator Serial Number
# 425                           Calibrator Serial Number
# 319                                       Casing Grade
# 18                                       Casing Layout
# 192                               Casing String Number
# 320                           Casing Bottom of Driller
# 321                           Logger Casing Shoe Depth
# 213                         Casing Collar Locator Gain
# 322                                  Casing Depth From
# 323                              Casing Outer Diameter
# 123            Correction for Delta-T Shale, Empirical
# 324                                       Casing Grade
# 170  County/Parish Label, used with the COUN parame...
# 381                       CMR Formation Water Salinity
# 85                                        Company Name
# 176                               Company Name, Line 1
# 179                                          Continent
# 172                                    Conveyance Type
# 67                      Surface coordinate system name
# 239                                   County or Parish
# 325                                     Casing Density
# 326                              Casing Inner Diameter
# 327                                Current Casing Size
# 294  Flag Indicating Presence of Liner Hanger in Ca...
# 114            Total Compressibility of Rock and Fluid
# 328                                      Casing Weight
# 329                              Casing Yield Strength
# 309                      Tools Above Rotary Table Date
# 282                                   Date Logged From
# 193                                     Date Logged To
# 310                           Date Circulation Stopped
# 140                              Depth Correction Mode
# 197                                 DC Main Cable Trim
# 20   Reference Acceptance Criteria for Magnetic Flu...
# 74   Reference Acceptance Criteria for Gravitationa...
# 58   Reference Acceptance Criteria for Magnetic Dip...
# 59       Acceptance Criteria for Magnetic Flux Density
# 33   Acceptance Criteria for Gravitational Field St...
# 65          Acceptance Criteria for Magnetic Dip Angle
# 126                                     Depth Remark 1
# 98                                      Depth Remark 2
# 251                                     Depth Remark 3
# 268                                     Depth Remark 4
# 117                                     Depth Remark 5
# 190                                     Depth Remark 6
# 214                                  Depth System Type
# 241                             Drilling Fluid Density
# 264                               Electrical Stability
# 187                                Drilling Fluid Loss
# 115                                  Drilling Fluid pH
# 387                                Drilling Fluid Type
# 256                        Drilling Fluid Total Solids
# 159                                Drilling Fluid Type
# 183                           Drilling Fluid Viscosity
# 369                             Default Fluid Velocity
# 96                  Drilling Fluid High Gravity Solids
# 1                                  Large Ring Diameter
# 2                                  Small Ring Diameter
# 281  Azimuth of a dipping plane in the Earth subsur...
# 133                                           District
# 311                              Date Logger At Bottom
# 38                              Enable DMAG Correction
# 68                                   DMAG Cutoff Depth
# 394  Drilling Measured From (Name of Drilling Eleva...
# 69    Direction and Inclination Inits Calculation Date
# 163                     Drilling Fluid Oil/water Ratio
# 132                         Depth System Serial Number
# 135                                      Delta-T Fluid
# 189                                     Delta-T Matrix
# 221                            Borehole Fluid Slowness
# 385                                    Delta-T for Mud
# 382
# 32                             Estimated Azimuth Error
# 395                         Elevation of Casing Flange
# 396                           Elevation of Drill Floor
# 77                  Estimated Drillstring Interference
# 397                          Elevation of Ground Level
# 398                         Elevation of Kelly Bushing
# 28                 Elevation of Logging Zero Reference
# 101                                    TBEI Emex Level
# 131                    TBEI Emex Input Power Limit [W]
# 194        Equipment or Computation Acquisition Status
# 195        Equipment or Computation Acquisition Status
# 196        Equipment or Computation Acquisition Status
# 55   Elevation of Permanent Datum (PDAT) above Mean...
# 436                        Depth measuring device type
# 433                                 Logging cable type
# 427                                Tension device type
# 13                      Elevation of the TIP above MSL
# 253                             eWAFE Baseline Version
# 108                 eWafe Telemetry Downlink Amplitude
# 166   eWafe Telemetry Downlink Filtering on DAC output
# 161  eWafe Telemetry Downlink Pulse Width (ADC samp...
# 284                      eWAFE System Firmware Version
# 231        eWafe Telemetry Uplink Filter Coefficient 0
# 165            eWafe Telemetry Uplink Threshold Factor
# 139                     Future Casing (Outer) Diameter
# 252                                      Fluid Density
# 386          Exponent "m" for Formation Factor Formula
# 113                          Formation Fluid Viscosity
# 130                                     Field Location
# 244                             Field Location, Line 1
# 174                             Field Location, Line 2
# 347                              Fluid Density (kg/m3)
# 34   Depth of Drilling Fluid Level to LMF (Log Meas...
# 201                                         Field Name
# 359           F-Numerator for Formation Factor Formula
# 334    Source of Porosity for Formation Factor Formula
# 335    Source of Porosity for Formation Factor Formula
# 238                                 Formation Salinity
# 355                        Fluid Interval Transit Time
# 352  Density of gas (air, hydrocarbon, etc.) at a p...
# 336                      Generalized Caliper Selection
# 337                      Generalized Caliper Selection
# 230                               Gas Downhole Density
# 364                               Gas Downhole Density
# 66   Average Angular Deviation of Borehole from Ver...
# 46                                        Geomag Model
# 80                        Geomag Model Year Infomation
# 279                                        Gas Gravity
# 142                                Geothermal Gradient
# 31                                  Magnetic Dip Angle
# 52                        Gravitational Field Strength
# 26                               Magnetic Flux Density
# 261                                      Gas Oil Ratio
# 383                                      Gas Oil Ratio
# 120  Confidence factor on cable depth used in GPIT ...
# 128  Ratio (average speed after sticking) / (averag...
# 289  Sticking detection threshold used in GPIT spee...
# 356                  Real-Time Formation Temp Gradient
# 53                          RST Grid Current Set Point
# 338              Generalized Mud Resistivity Selection
# 339              Generalized Mud Resistivity Selection
# 341                  Generalized Temperature Selection
# 340                  Generalized Temperature Selection
# 263                                      Gas Viscosity
# 152                          Coordinate system adopted
# 421                                Header Identifier 1
# 422                                Header Identifier 2
# 420                                  Header Identifier
# 218                  Hydrogen Index of Formation Fluid
# 354                          HILT Gas Downhole Density
# 343           Integrated Hole Volume Caliper Selection
# 342           Integrated Hole Volume Caliper Selection
# 216                1/Gas Formation Volume Factor, 1/Bg
# 36   Ignore Depth-Log Passes Made Faster Than This ...
# 17        Ignore Depth-Log Passes Shallower Than Depth
# 48       Ignore Depth-Log Passes Shorter Than Interval
# 49                          Ignore Stations-Log Passes
# 39        Ignore Stations-Log Passes Shorter Than Time
# 119                     Integrated Hole Volume Control
# 351                 Integrated Hole Volume Start Value
# 186  Boolean Flag to Indicate Whether System is in ...
# 0                               Jig gamma_ray Strength
# 220                                 Job Identification
# 374
# 37                                  Latitude (N=+ S=-)
# 25                                            Latitude
# 260       Logging Company Code (API DLIS Company Code)
# 148                               Logging Company Name
# 434                               Logging Cable Length
# 297                        Logging Cable Serial Number
# 27                        Local Computation Definition
# 94   Section/Latitude Label, used with the SECT or ...
# 23   Logging Measured From (Name of Logging Elevati...
# 169  Identification mnemonic for the logging operation
# 333                                  Location - 1 Text
# 75                        Gravitational Field Strength
# 227                                       Log Sequence
# 91                                         Type of log
# 86                                 Log Start Date/Time
# 127                                 Log Stop Date/Time
# 62                                           Longitude
# 12                                           Longitude
# 236                                    Type of service
# 177                              Logging Unit Location
# 93                                 Logging Unit Number
# 102  Exponent M of the Archie Formation Factor - Po...
# 22   Flag for manually entering the grid convergenc...
# 388       Rock Matrix for Neutron Porosity Corrections
# 185                   Toolstring Maximum Logging Speed
# 274                              Mudcake Sample Source
# 137                         Mudcake Sample Temperature
# 9                           Magnetic Field Declination
# 10                          Magnetic Field Declination
# 389                Matrix Density for Density Porosity
# 47                  Merge Depth-Log Passes If Possible
# 211                                   Messages to Skip
# 212                                   Messages to Skip
# 15                            Magnetic Field Intensity
# 286                         Mud Filtrate Sample Source
# 118                    Mud Filtrate Sample Temperature
# 105                             Maximum Hole Deviation
# 44                          Magnetic Field Inclination
# 380                                    Mud Resistivity
# 11                        Maximum Recorded Temperature
# 14                      Maximum Recorded Temperature 1
# 73                      Maximum Recorded Temperature 2
# 16                      Maximum Recorded Temperature 3
# 87                                   Mud Sample Source
# 81                              Mud Sample Temperature
# 349                        Mud Sample Temperature (RM)
# 265                             Mud Filtrate Viscosity
# 368                                         Mud Weight
# 344                                    Mud Weight (RM)
# 90                            N Exponent in SW Formula
# 224                                             Nation
# 8                                      North Reference
# 390                                 Oil Based Mud Flag
# 156                               Oil Downhole Density
# 376                               Oil Downhole Density
# 262                                        Oil Density
# 204  Identification of the Offshore block where the...
# 112                                Surface Oil Gravity
# 348                                     Gravity of Oil
# 375                          Origin of Mud Resistivity
# 350  Origin of Mud Resistivity [CONS(def), AMS, DEP...
# 245              Operator Code (API DLIS Company Code)
# 415                              Other Services Line 1
# 416                              Other Services Line 2
# 417                              Other Services Line 3
# 418                              Other Services Line 4
# 419                              Other Services Line 5
# 40                      Override Magnetic Flux Density
# 42               Override Gravitational Field Strength
# 4                  Override Magnetic Declination Angle
# 57                         Override Magnetic Dip Angle
# 144                                      Oil Viscosity
# 54        Allow Pauses Time Interval During Log Passes
# 164  Packer Inner Diameter - Zoned along driller de...
# 121  Packer Outer Diameter - Zoned along driller de...
# 82                                     Permanent Datum
# 167                                           Porosity
# 141                                   Telephone number
# 205   Plug Outer Diameter - Zoned along driller depths
# 366                     Potassium Concentration in Mud
# 312                                    Program Version
# 235                                     Remarks Line 1
# 100                                    Remarks Line 10
# 103                                    Remarks Line 11
# 269                                    Remarks Line 12
# 267                                    Remarks Line 13
# 173                                    Remarks Line 14
# 243                                    Remarks Line 15
# 223                                    Remarks Line 16
# 247                                    Remarks Line 17
# 206                                     Remarks Line 2
# 229                                     Remarks Line 3
# 200                                     Remarks Line 4
# 285                                     Remarks Line 5
# 184                                     Remarks Line 6
# 232                                     Remarks Line 7
# 191                                     Remarks Line 9
# 272                                              Range
# 154                     Additional RB offset (degrees)
# 293                    Requested Perforation Intervals
# 360                     Density of the Formation Fluid
# 151  Rig Daylight Saving Time. (0 Means Unknown, 1 ...
# 207                                           Rig Name
# 175                                           Rig Type
# 171  Difference, in Hours, Between UTC (Coordinated...
# 225  Range/Blank Label, used with the RANG paramete...
# 249                   Reference Log Date (dd-MMM-yyyy)
# 266                                 Reference Log Name
# 215                           Reference Log Run Number
# 70       Resistivity of Mud at Bottom Hole Temperature
# 60     Mud Cake Resistivity at Bottom Hole Temperature
# 202                     Resistivity of Mud Cake Sample
# 30   Resistivity of Mud Filtrate At Bottom Hole Tem...
# 182                 Resistivity of Mud Filtrate Sample
# 79                           Resistivity of Mud Sample
# 357                     Resistivity of Mud Sample (RM)
# 358                          Resistivity of Mud Sample
# 370                   Resistivity of Mud Sample (SRTX)
# 234                     Density of Mud Filtrate Sample
# 308                                 Run Remark Line 10
# 306                                  Run Remark Line 2
# 304                                  Run Remark Line 3
# 305                                  Run Remark Line 4
# 307                                  Run Remark Line 5
# 303                                  Run Remark Line 6
# 300                                  Run Remark Line 7
# 299                                  Run Remark Line 8
# 301                                  Run Remark Line 9
# 365                      Real-Time Surface Temperature
# 384                             Real-Time Mud Salinity
# 222                            Rig Up Length at Bottom
# 153                           Rig Up Length at Surface
# 209                                         Run Number
# 391                                      Pipe Rugosity
# 147                          Connate Water Resistivity
# 99                              Free Water Resistivity
# 45                            Water Sample Resistivity
# 50                               Enable Sag Correction
# 203                           Cable Stretch Correction
# 393                                        Water Depth
# 237                                    Section #1 Gain
# 292                                    Section #2 Gain
# 242                                    Section #3 Gain
# 92                                             Section
# 362                           HILT Saturation Exponent
# 248  Slowness Formation Type (Fast, Intermediate, S...
# 283                             Solution Gas Oil Ratio
# 5                             Surface Hole Temperature
# 361                      Surface Hole Temperature (RM)
# 150                  Log data generated by a simulator
# 122  State/Province Label, used with the STAT param...
# 21         Amount of down-movement when going in slips
# 129                               Service Order Number
# 295                                     Shots per Foot
# 392                             Sonic Porosity Formula
# 138            Start date when the well drilling began
# 275                                  State or Province
# 257                Subsequent Trip Down Log Correction
# 371                                Surface Temperature
# 104                               Stuck Tool Threshold
# 24               TBEI Fixed Image Gain (0 = normalise)
# 19                TBEI Histogram Equalisation Allowed?
# 3             TBEI Convert Button Data to Conductance?
# 35                    TBEI Apply Image Phase Rotation?
# 71   TBEI Phase Rotation by Pad: Skip first and las...
# 51    TBEI Phase Rotation by Pad (yes) or Button (no)?
# 84        TBEI Minimum Valid Points in Rotation Window
# 83                   TBEI Rotation Amplitude Threshold
# 29                    TBEI Rotation Computation Window
# 6                            TBEI Zoned Rotation Angle
# 78                   TBEI Use Zoned Rotation Angle(s)?
# 254                                       Tubing Depth
# 313                           Time Circulation Stopped
# 61                                Total Measured Depth
# 330                                Driller Total Depth
# 331                                 Logger Total Depth
# 428  Calibration coefficient gain used for Tension ...
# 432  Calibration coefficient offset used for Tensio...
# 429     Calibration Peak Error Used for Tension Device
# 431         Calibration Points Used for Tension Device
# 430  Calibration Root Mean Square Error Used for Te...
# 345                                   Total Depth (RM)
# 288        Tests and Diagnostics Tasks Tolerance Level
# 188                       Telemetry Downlink Amplitude
# 146  Telemetry Downlink Pulse Width (ADC sample per...
# 291              Telemetry Uplink Filter Coefficient 0
# 107              Telemetry Uplink Filter Coefficient 1
# 255              Telemetry Uplink Filter Coefficient 2
# 124              Telemetry Uplink Filter Coefficient 3
# 290                  Telemetry Uplink Threshold Factor
# 353                                     Fluid velocity
# 332                        Nominal Thickness of Casing
# 314                              Time Logger At Bottom
# 273                                   Top Log Interval
# 110  Township or Longitude Label for Log Heading, u...
# 298               Borehole Correction Option (for TMG)
# 296                       Tension Device Serial Number
# 210                                Tool or tool string
# 399                                    Tool Object Map
# 408                                    Tool Object Map
# 409                                    Tool Object Map
# ...
# 364                              [0.10000000149011612]
# 66                                               [0.0]
# 46                                              [BGGM]
# 80                                              [2019]
# 279                                          [-999.25]
# 142                                              [1.0]
# 31                                 [64.03931427001953]
# 52                                 [32.15388107299805]
# 26                                    [50059.90234375]
# 261                                          [-999.25]
# 383                                          [-999.25]
# 120                                              [3.0]
# 128                                              [3.0]
# 289                              [0.06561679393053055]
# 356                                              [1.0]
# 53                                               [0.0]
# 338                                             [GEN9]
# 339                                             [GEN9]
# 341                                             [TEMP]
# 340                                             [TEMP]
# 263                             [0.019999999552965164]
# 152                                            [SAD69]
# 421                                                 []
# 422                                                 []
# 420                                                 []
# 218                                              [1.0]
# 354                              [0.10000000149011612]
# 343                                               [BS]
# 342                                               [BS]
# 216                                          [-999.25]
# 36                                           [20000.0]
# 17                                            [-100.0]
# 48                                              [50.0]
# 49                                                [No]
# 39                                             [300.0]
# 119                                            [START]
# 351                                          [-999.25]
# 186                                               [No]
# 0                                              [150.0]
# 220                                   [UniversityUtah]
# 374                                              [0.0]
# 37                                 [38.50401306152344]
# 25                          [b'38\xb0 30\' 14.447" N']
# 260                                              [440]
# 148                                     [Schlumberger]
# 434                                 [15899.9990234375]
# 297                                          [U714070]
# 27                                                  []
# 94                                           [Section]
# 23                                                [KB]
# 169                                                 []
# 333               [1043' S & 495' E from W4 Corner of]
# 75                                 [32.15388107299805]
# 227                            [First Log In the Well]
# 91                                                  []
# 86                                           [44193.0]
# 127                               [44193.331238425926]
# 62                               [-112.89640808105469]
# 12                         [b'112\xb0 53\' 47.066" W']
# 236                                                 []
# 177                                  [Fort Morgan, CO]
# 93                                              [2801]
# 102                                              [2.0]
# 22                                                 [0]
# 388                                             [LIME]
# 185                                          [-999.25]
# 274                                       [Calculated]
# 137                                             [68.0]
# 9                                 [11.415133476257324]
# 10                                [11.415133476257324]
# 389                               [2.7100000381469727]
# 47                                               [Yes]
# 211                                               [50]
# 212                                               [50]
# 15                                [0.5005990266799927]
# 286                                       [Calculated]
# 118                                             [68.0]
# 105                                              [0.0]
# 44                                 [64.03931427001953]
# 380                              [0.20000000298023224]
# 11                                             [322.0]
# 14                                             [322.0]
# 73                                           [-999.25]
# 16                                           [-999.25]
# 87                                       [Active Tank]
# 81                                              [68.0]
# 349                                             [68.0]
# 265                                              [1.0]
# 368                                              [9.0]
# 344                                              [9.0]
# 90                                               [2.0]
# 224                                                 []
# 8                                                  [0]
# 390                                               [NO]
# 156                                [0.800000011920929]
# 376                                [0.800000011920929]
# 262                                          [-999.25]
# 204                                                 []
# 112                                          [-999.25]
# 348                                          [-999.25]
# 375                                      [Active Tank]
# 350                                      [Active Tank]
# 245                                                 []
# 415                                                 []
# 416                                                 []
# 417                                                 []
# 418                                                 []
# 419                                                 []
# 40                                                 [0]
# 42                                                 [0]
# 4                                                  [0]
# 57                                                 [0]
# 144                                              [1.0]
# 54                                            [7200.0]
# 164                                          [-999.25]
# 121                                          [-999.25]
# 82                                                [GL]
# 167                              [0.20000000298023224]
# 141                                                 []
# 205                                          [-999.25]
# 366                                              [0.0]
# 312                                         [20C0-999]
# 235             [Thank you for choosing Schlumberger!]
# 100                                                 []
# 103                                                 []
# 269                                                 []
# 267                                                 []
# 173                                                 []
# 243                                                 []
# 223                                                 []
# 247                                                 []
# 206  [Correlated to second descent dated 25-NOV-2020.]
# 229  [Chilled mud was pumped to cool well to beneat...
# 200                                                 []
# 285                                                 []
# 184                  [Tool was run as per tool sketch]
# 232      [All logging intervals as per client request]
# 191                                                 []
# 272                                               [9W]
# 154                                              [0.0]
# 293                                      [[[-999.25]]]
# 360                                              [1.0]
# 151                                                [1]
# 207                            [Frontier Drilling #16]
# 175                                             [Land]
# 171                                             [-7.0]
# 225                                            [Range]
# 249                                                 []
# 266                                                 []
# 215                                                 []
# 70                               [0.05403042212128639]
# 60                                           [-999.25]
# 202                                          [-999.25]
# 30                               [0.04052281752228737]
# 182                              [0.15000000596046448]
# 79                               [0.20000000298023224]
# 357                              [0.20000000298023224]
# 358                              [0.20000000298023224]
# 370                              [0.20000000298023224]
# 234                                              [1.0]
# 308                                                 []
# 306                                                 []
# 304                                                 []
# 305                                                 []
# 307                                                 []
# 303                                                 []
# 300                                                 []
# 299                                                 []
# 301                                                 []
# 365                                             [68.0]
# 384                                           [1500.0]
# 222                                          [-999.25]
# 153                                          [-999.25]
# 209                                               [17]
# 391                            [0.0004916666657663882]
# 147                                              [1.0]
# 99                                               [1.0]
# 45                                               [1.0]
# 50                                                 [0]
# 203                                          [-999.25]
# 393                                          [-999.25]
# 237                                             [Auto]
# 292                                             [Auto]
# 242                                             [Auto]
# 92                                                [32]
# 362                                              [2.0]
# 248                                     [Intermediate]
# 283                                          [-999.25]
# 5                                               [68.0]
# 361                                             [68.0]
# 150                                               [No]
# 122                                           [State:]
# 21                                               [2.0]
# 129                                                 []
# 295                                                 []
# 392                                              [R_H]
# 138                                                 []
# 275                                             [Utah]
# 257                                          [-999.25]
# 371                                             [68.0]
# 104                                              [2.5]
# 24                                               [1.0]
# 19                                                [No]
# 3                                                 [No]
# 35                                                [No]
# 71                                                [No]
# 51                                               [Yes]
# 84                                               [5.0]
# 83                                               [3.0]
# 29                                              [50.0]
# 6                                                [0.0]
# 78                                                [No]
# 254                                          [-999.25]
# 313                                                 []
# 61                                           [10987.0]
# 330                                          [10906.0]
# 331                                          [10906.0]
# 428                                              [1.0]
# 432                                              [0.0]
# 429                                             [49.0]
# 431                                               [10]
# 430                                             [28.0]
# 345                                          [10987.0]
# 288                                             [Shop]
# 188                                              [1.0]
# 146                                                [6]
# 291                                              [1.0]
# 107                                              [0.0]
# 255                                              [0.0]
# 124                                              [0.0]
# 290                              [0.30000001192092896]
# 353                                            [189.0]
# 332                              [0.39500001072883606]
# 314                                         [17:00:00]
# 273                                          [-999.25]
# 110                                         [Township]
# 298                                          [CALIPER]
# 296                                             [5036]
# 210                                                 []
# 399  [<ToolMaps><ToolMap><HN>TENSION_DEVICE</HN><MN...
# 408  [an>RC3_13</Chan><Chan>CINCC</Chan><Chan>BE3_Q...
# 409  [an>BG2_Q</Chan><Chan>APGA2_3</Chan><Chan>C2CC...
# 410  [APGA1_2</Chan><Chan>E13M</Chan><Chan>EMSTS</C...
# 411  [><Chan>BB3_P</Chan><Chan>ABST_2</Chan><Chan>C...
# 412  [Chan><Chan>CMEC</Chan><Chan>A5VP_1</Chan><Cha...
# 413  [/Chan><Chan>TBEI_DEVI</Chan><Chan>BE2_P</Chan...
# 414  [-A</HN><MN>TBT</MN><InsNo>0</InsNo><CopNo>0</...
# 400  [o></ToolMap><ToolMap><HN>LOGGING_CABLE</HN><M...
# 401  [0</CopNo><Channels><Chan>CCPU</Chan><Chan>EV5...
# 402  [n>TBEI_AZ</Chan><Chan>C1CC</Chan><Chan>ABST_1...
# 403  [an>S5VD_3</Chan><Chan>APGA2_4</Chan><Chan>A5V...
# 404  [<Chan>ACPU_2</Chan><Chan>BF2_Q</Chan><Chan>RC...
# 405  [><Chan>ACPU_3</Chan><Chan>TBEI_RB</Chan><Chan...
# 406  [C</Chan><Chan>C2RC</Chan><Chan>C3CC_R</Chan><...
# 407  [an><Chan>APGA3_4</Chan><Chan>RC2_24</Chan><Ch...
# 7                                 [11.415133476257324]
# 278                                              [26S]
# 160                                       [Eccentered]
# 246                                          [-999.25]
# 76                                              [68.0]
# 373                                             [68.0]
# 155                                                 []
# 43                                           [-999.25]
# 270                                          [-999.25]
# 377                                              [1.0]
# 111                                          [-999.25]
# 88                                           [-999.25]
# 125                                              [1.0]
# 41                                           [-999.25]
# 437                                             [-6.0]
# 438                                             [-8.0]
# 228  [<PowerCollection><PowerSupply><PowerType>WL_P...
# 372                                              [9.0]
# 379                                              [9.0]
# 276                                 [Forge 16A(78)-32]
# 198                                          [-999.25]
# 367                                          [-999.25]
# 217                                              [0.5]
# 277                               [1.4800000190734863]
# 233                                          [-999.25]
