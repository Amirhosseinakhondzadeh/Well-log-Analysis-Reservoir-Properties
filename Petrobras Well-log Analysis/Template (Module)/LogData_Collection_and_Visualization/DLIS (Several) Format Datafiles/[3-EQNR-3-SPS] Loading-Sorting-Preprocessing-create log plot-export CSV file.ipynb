# %% [markdown]
# <span style='color:Blue'> <span style="font-size:25px;"> **[3-EQNR-3-SPS] Loading-Sorting-Preprocessing-create log plot-export CSV file of a DLIS file**

# %%
# %%capture

# %pip install dlisio                                                   
# %pip install qbstyles                                                 
# %pip install folium 
# %pip install geopandas

from dlisio import dlis
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
import matplotlib.patches as mpatches                                 

import folium                                                         
from folium import plugins 
import json                                                           

from qbstyles import mpl_style
mpl_style(dark=False)                                                 

from matplotlib_inline.backend_inline import set_matplotlib_formats   
set_matplotlib_formats('svg')

# %% [markdown]
# <span style='color:black'> <span style="font-size:30px;"> **3-EQNR-3-SPS**

# %% [markdown]
# <span style='color:brown'> <span style="font-size:19px;"> **STEP 2: load all the required DLIS files**

# %%
dlis0, *tail0 = dlis.load('/Users/amirhosseinakhondzadeh/@ DATA/3-EQNR-3-SPS/Perfis Digitais/3eqnr3sps_ait_quantageo_gr_001-22973.dlis')
dlis1, *tail1 = dlis.load('/Users/amirhosseinakhondzadeh/@ DATA/3-EQNR-3-SPS/Perfis Digitais/3eqnr3sps_ait_quantageo_gr_002-22975.dlis')
dlis2, *tail2 = dlis.load('/Users/amirhosseinakhondzadeh/@ DATA/3-EQNR-3-SPS/Perfis Digitais/3eqnr3sps_ait_quantageo_gr_003-22983.dlis')

dlis3, *tail3 = dlis.load('/Users/amirhosseinakhondzadeh/@ DATA/3-EQNR-3-SPS/Perfis Digitais/3eqnr3sps_ait_tld_hgns_quantageo_gr_016-22956.dlis')
dlis4, *tail4 = dlis.load('/Users/amirhosseinakhondzadeh/@ DATA/3-EQNR-3-SPS/Perfis Digitais/3eqnr3sps_ait_tld_hgns_quantageo_gr_026-22985.dlis')
dlis5, *tail5 = dlis.load('/Users/amirhosseinakhondzadeh/@ DATA/3-EQNR-3-SPS/Perfis Digitais/3eqnr3sps_ait_tld_hgns_quantageo_gr_034-22971.dlis')
dlis6, *tail6 = dlis.load('/Users/amirhosseinakhondzadeh/@ DATA/3-EQNR-3-SPS/Perfis Digitais/3eqnr3sps_ait_tld_hgns_quantageo_gr_105-22963.dlis')
dlis7, *tail7 = dlis.load('/Users/amirhosseinakhondzadeh/@ DATA/3-EQNR-3-SPS/Perfis Digitais/3eqnr3sps_ait_tld_hgns_quantageo_gr_113-22968.dlis')
dlis8, *tail8 = dlis.load('/Users/amirhosseinakhondzadeh/@ DATA/3-EQNR-3-SPS/Perfis Digitais/3eqnr3sps_ccl_006-23074.dlis')
dlis9, *tail9 = dlis.load('/Users/amirhosseinakhondzadeh/@ DATA/3-EQNR-3-SPS/Perfis Digitais/3eqnr3sps_ccl_007-23073.dlis')

dlis10, *tail10 = dlis.load('/Users/amirhosseinakhondzadeh/@ DATA/3-EQNR-3-SPS/Perfis Digitais/3eqnr3sps_cmr_gr_001-22987.dlis')
dlis11, *tail11 = dlis.load('/Users/amirhosseinakhondzadeh/@ DATA/3-EQNR-3-SPS/Perfis Digitais/3eqnr3sps_cmr_gr_016-22966.dlis')
dlis12, *tail12 = dlis.load('/Users/amirhosseinakhondzadeh/@ DATA/3-EQNR-3-SPS/Perfis Digitais/3eqnr3sps_cmr_gr_117-22967.dlis')
dlis13, *tail13 = dlis.load('/Users/amirhosseinakhondzadeh/@ DATA/3-EQNR-3-SPS/Perfis Digitais/3eqnr3sps_cmr_next_hngs_gr_035-22986.dlis')
dlis14, *tail14 = dlis.load('/Users/amirhosseinakhondzadeh/@ DATA/3-EQNR-3-SPS/Perfis Digitais/3eqnr3sps_cmr_next_hngs_gr_072-22955.dlis')
dlis15, *tail15 = dlis.load('/Users/amirhosseinakhondzadeh/@ DATA/3-EQNR-3-SPS/Perfis Digitais/3eqnr3sps_cmr_next_hngs_gr_085-22959.dlis')
dlis16, *tail16 = dlis.load('/Users/amirhosseinakhondzadeh/@ DATA/3-EQNR-3-SPS/Perfis Digitais/3eqnr3sps_cmr_next_hngs_gr_100-22969.dlis')
dlis17, *tail17 = dlis.load('/Users/amirhosseinakhondzadeh/@ DATA/3-EQNR-3-SPS/Perfis Digitais/3eqnr3sps_cmr_tld_hgns_gr_002-22960.dlis')
dlis18, *tail18 = dlis.load('/Users/amirhosseinakhondzadeh/@ DATA/3-EQNR-3-SPS/Perfis Digitais/3eqnr3sps_cmr_tld_hgns_gr_003-22954.dlis')

dlis19, *tail19 = dlis.load('/Users/amirhosseinakhondzadeh/@ DATA/3-EQNR-3-SPS/Perfis Digitais/3eqnr3sps_next_hngs_gr_003-22976.dlis')
dlis20, *tail20 = dlis.load('/Users/amirhosseinakhondzadeh/@ DATA/3-EQNR-3-SPS/Perfis Digitais/3eqnr3sps_next_hngs_gr_005-22978.dlis')
dlis21, *tail21 = dlis.load('/Users/amirhosseinakhondzadeh/@ DATA/3-EQNR-3-SPS/Perfis Digitais/3eqnr3sps_next_hngs_gr_018-22970.dlis')
dlis22, *tail22 = dlis.load('/Users/amirhosseinakhondzadeh/@ DATA/3-EQNR-3-SPS/Perfis Digitais/3eqnr3sps_next_hngs_gr_019-22981.dlis')
dlis23, *tail23 = dlis.load('/Users/amirhosseinakhondzadeh/@ DATA/3-EQNR-3-SPS/Perfis Digitais/3eqnr3sps_next_hngs_gr_053-22988.dlis')
dlis24, *tail24 = dlis.load('/Users/amirhosseinakhondzadeh/@ DATA/3-EQNR-3-SPS/Perfis Digitais/3eqnr3sps_next_hngs_gr_069-22984.dlis')
dlis25, *tail25 = dlis.load('/Users/amirhosseinakhondzadeh/@ DATA/3-EQNR-3-SPS/Perfis Digitais/3eqnr3sps_next_hngs_gr_125-22958.dlis')

dlis26, *tail26 = dlis.load('/Users/amirhosseinakhondzadeh/@ DATA/3-EQNR-3-SPS/Perfis Digitais/3eqnr3sps_pbms_pfcs_002-23061.dlis')
dlis27, *tail27 = dlis.load('/Users/amirhosseinakhondzadeh/@ DATA/3-EQNR-3-SPS/Perfis Digitais/3eqnr3sps_pbms_pfcs_116-23040.dlis')

dlis28, *tail28 = dlis.load('/Users/amirhosseinakhondzadeh/@ DATA/3-EQNR-3-SPS/Perfis Digitais/3eqnr3sps_ubi_msip_gr_001-22962.dlis')
dlis29, *tail29 = dlis.load('/Users/amirhosseinakhondzadeh/@ DATA/3-EQNR-3-SPS/Perfis Digitais/3eqnr3sps_ubi_msip_gr_002-22974.dlis')
dlis30, *tail30 = dlis.load('/Users/amirhosseinakhondzadeh/@ DATA/3-EQNR-3-SPS/Perfis Digitais/3eqnr3sps_ubi_msip_gr_003-22961.dlis')
dlis31, *tail31 = dlis.load('/Users/amirhosseinakhondzadeh/@ DATA/3-EQNR-3-SPS/Perfis Digitais/3eqnr3sps_ubi_msip_gr_051-22964.dlis')
dlis32, *tail32 = dlis.load('/Users/amirhosseinakhondzadeh/@ DATA/3-EQNR-3-SPS/Perfis Digitais/3eqnr3sps_ubi_msip_gr_056-22977.dlis')
dlis33, *tail33 = dlis.load('/Users/amirhosseinakhondzadeh/@ DATA/3-EQNR-3-SPS/Perfis Digitais/3eqnr3sps_ubi_msip_gr_088-22982.dlis')
dlis34, *tail34 = dlis.load('/Users/amirhosseinakhondzadeh/@ DATA/3-EQNR-3-SPS/Perfis Digitais/3eqnr3sps_ubi_msip_gr_126-22972.dlis')

dlis35, *tail35 = dlis.load('/Users/amirhosseinakhondzadeh/@ DATA/3-EQNR-3-SPS/Perfis Digitais/3eqnr3sps_ubi_ppc_msip_gr_001-22979.dlis')
dlis36, *tail36 = dlis.load('/Users/amirhosseinakhondzadeh/@ DATA/3-EQNR-3-SPS/Perfis Digitais/3eqnr3sps_ubi_ppc_msip_gr_004-22957.dlis')
dlis37, *tail37 = dlis.load('/Users/amirhosseinakhondzadeh/@ DATA/3-EQNR-3-SPS/Perfis Digitais/3eqnr3sps_ubi_ppc_msip_gr_014-22980.dlis')
dlis38, *tail38 = dlis.load('/Users/amirhosseinakhondzadeh/@ DATA/3-EQNR-3-SPS/Perfis Digitais/3eqnr3sps_ubi_ppc_msip_gr_124-22953.dlis')

dlis39, *tail39 = dlis.load('/Users/amirhosseinakhondzadeh/@ DATA/3-EQNR-3-SPS/Perfis Digitais/3eqnr3sps_upct_032-22965.dlis')

# %%
# Define a list of dlis object names (assuming dlis0, dlis1, ..., dlis9 exist)
dlis_names = [f'dlis{i}' for i in range(40)]

# Define depth_units
depth_units = "in"  # Replace "units" with the actual units you want to use

for dlis_name in dlis_names:
    dlis = globals()[dlis_name]  # Get the dlis object using its name
    print("=" * 80)
    print(f"DLIS Object: {dlis_name}")
    print("=" * 80)

    for frame in dlis.frames:
        print(f"Frame Name:         {frame.name}")
        print(f"Number of Channels: {len(frame.channels)}")
        print(f"Depth Interval:     {frame.index_min} - {frame.index_max} {depth_units}")
        print(f"Depth Spacing:      {frame.spacing} {depth_units}")
        print(f"Channel Names:      {', '.join(channel.name for channel in frame.channels)}")
        print("-" * 80)

    print("%" * 80)
# Out:
# ...
# DLIS Object: dlis0
# ...
# Frame Name:         1B
# Number of Channels: 131
# Depth Interval:     2496063.0 - 2575377.0 in
# Depth Spacing:      1.0 in
# ...

# %% [markdown]
# <span style='color:green'> <span style="font-size:19px;"> **STEP 2: create Pandas DataFrames containing all the required Well Log Data**

# %%
# Create variable "f" which stands for frame

f0 = dlis0.object('FRAME','60B') # GR
f1 = dlis0.object('FRAME','30B') # AT10, AT20, AT30, AT60, AT90

f2 = dlis1.object('FRAME','60B') # GR
f3 = dlis1.object('FRAME','30B') # AT10, AT20, AT30, AT60, AT90

f4 = dlis2.object('FRAME','60B') # GR
f5 = dlis2.object('FRAME','30B') # AT10, AT20, AT30, AT60, AT90

f6 = dlis3.object('FRAME','60B') # NPHI 
f7 = dlis3.object('FRAME','20B') # RHOZ, PEFZ
f8 = dlis3.object('FRAME','30B') # AT10, AT20, AT30, AT60, AT90

f9 = dlis4.object('FRAME','60B') # NPHI 
f10 = dlis4.object('FRAME','20B') # RHOZ, PEFZ
f11 = dlis4.object('FRAME','30B') # AT10, AT20, AT30, AT60, AT90

f12 = dlis5.object('FRAME','60B') # NPHI 
f13 = dlis5.object('FRAME','20B') # RHOZ, PEFZ
f14 = dlis5.object('FRAME','30B') # AT10, AT20, AT30, AT60, AT90

f15 = dlis6.object('FRAME','60B') # NPHI 
f16 = dlis6.object('FRAME','20B') # RHOZ, PEFZ
f17 = dlis6.object('FRAME','30B') # AT10, AT20, AT30, AT60, AT90

f18 = dlis7.object('FRAME','60B') # NPHI 
f19 = dlis7.object('FRAME','20B') # RHOZ, PEFZ
f20 = dlis7.object('FRAME','30B') # AT10, AT20, AT30, AT60, AT90

f21 = dlis10.object('FRAME','60B') # GR
f22 = dlis10.object('FRAME','75B') # NMR

f23 = dlis11.object('FRAME','60B') # GR
f24 = dlis11.object('FRAME','75B') # NMR

f25 = dlis12.object('FRAME','60B') # GR
f26 = dlis13.object('FRAME','60B') # GR
f27 = dlis14.object('FRAME','60B') # GR

f28 = dlis15.object('FRAME','60B') # GR
f29 = dlis15.object('FRAME','75B') # NMR

f30 = dlis16.object('FRAME','60B') # GR
f31 = dlis16.object('FRAME','75B') # NMR

f32 = dlis17.object('FRAME','60B') # NPHI 
f33 = dlis17.object('FRAME','20B') # RHOZ, PEFZ
f34 = dlis17.object('FRAME','75B') # NMR

f35 = dlis18.object('FRAME','60B') # NPHI 
f36 = dlis18.object('FRAME','20B') # RHOZ, PEFZ
f37 = dlis18.object('FRAME','75B') # NMR

f38 = dlis21.object('FRAME','60B') # GR
f39 = dlis23.object('FRAME','60B') # GR
f40 = dlis24.object('FRAME','60B') # GR
f41 = dlis25.object('FRAME','60B') # GR
f42 = dlis26.object('FRAME','60B') # GR
f43 = dlis27.object('FRAME','60B') # GR

f44 = dlis28.object('FRAME','60B') # DTCO
f45 = dlis29.object('FRAME','60B') # DTCO
f46 = dlis30.object('FRAME','60B') # DTCO
f47 = dlis31.object('FRAME','60B') # DTCO
f48 = dlis32.object('FRAME','60B') # DTCO
f49 = dlis33.object('FRAME','60B') # DTCO
f50 = dlis34.object('FRAME','60B') # DTCO
f51 = dlis35.object('FRAME','60B') # DTCO
f52 = dlis36.object('FRAME','60B') # DTCO
f53 = dlis37.object('FRAME','60B') # DTCO
f54 = dlis38.object('FRAME','60B') # DTCO

f55 = dlis39.object('FRAME','60B') # GR

# %%
# Create variables "c" which stands for channel
c0 = f0.curves()
c1 = f1.curves()
c2 = f2.curves()
c3 = f3.curves()
c4 = f4.curves()
c5 = f5.curves()
c6 = f6.curves()
c7 = f7.curves()
c8 = f8.curves()
c9 = f9.curves()
c10 = f10.curves()
c11 = f11.curves()
c12 = f12.curves()
c13 = f13.curves()
c14 = f14.curves()
c15 = f15.curves()
c16 = f16.curves()
c17 = f17.curves()
c18 = f18.curves()
c19 = f19.curves()
c20 = f20.curves()
c21 = f21.curves()
c22 = f22.curves()
c23 = f23.curves()
c24 = f24.curves()
c25 = f25.curves()
c26 = f26.curves()
c27 = f27.curves()
c28 = f28.curves()
c29 = f29.curves()
c30 = f30.curves()
c31 = f31.curves()
c32 = f32.curves()
c33 = f33.curves()
c34 = f34.curves()
c35 = f35.curves()
c36 = f36.curves()
c37 = f37.curves()
c38 = f38.curves()
c39 = f39.curves()
c40 = f40.curves()
c41 = f41.curves()
c42 = f42.curves()
c43 = f43.curves()
c44 = f44.curves()
c45 = f45.curves()
c46 = f46.curves()
c47 = f47.curves()
c48 = f48.curves()
c49 = f49.curves()
c50 = f50.curves()
c51 = f51.curves()
c52 = f52.curves()
c53 = f53.curves()
c54 = f54.curves()
c55 = f55.curves()

# %%
# Define the channels/logging curves of interest for each frame "f"
# Convert DEPTH values to metres, by multiplying by 0.00254. 
# *0.00254

d0  = {'DEPTH'     : c0['TDEP']*0.00254,
       'GR'        : c0['GR']}

d1  = {'DEPTH'     : c1['TDEP']*0.00254,
       'AT10'      : c1['AT10'],
       'AT20'      : c1['AT20'],
       'AT30'      : c1['AT30'],
       'AT60'      : c1['AT60'],
       'AT90'      : c1['AT90']}

d2  = {'DEPTH'     : c2['TDEP']*0.00254,
       'GR'        : c2['GR']}

d3  = {'DEPTH'     : c3['TDEP']*0.00254,
       'AT10'      : c3['AT10'],
       'AT20'      : c3['AT20'],
       'AT30'      : c3['AT30'],
       'AT60'      : c3['AT60'],
       'AT90'      : c3['AT90']}

d4  = {'DEPTH'     : c4['TDEP']*0.00254,
       'GR'        : c4['GR']}

d5  = {'DEPTH'     : c5['TDEP']*0.00254,
       'AT10'      : c5['AT10'],
       'AT20'      : c5['AT20'],
       'AT30'      : c5['AT30'],
       'AT60'      : c5['AT60'],
       'AT90'      : c5['AT90']}

d6  = {'DEPTH'     : c6['TDEP']*0.00254,
       'NPHI'      : c6['NPHI']}

d7  = {'DEPTH'     : c7['TDEP']*0.00254,
       'RHOZ'      : c7['RHOZ'],
       'PEFZ'      : c7['PEFZ']}

d8  = {'DEPTH'     : c8['TDEP']*0.00254,
       'AT10'      : c8['AT10'],
       'AT20'      : c8['AT20'],
       'AT30'      : c8['AT30'],
       'AT60'      : c8['AT60'],
       'AT90'      : c8['AT90']}

d9  = {'DEPTH'     : c9['TDEP']*0.00254,
       'NPHI'      : c9['NPHI']}

d10  = {'DEPTH'    : c10['TDEP']*0.00254,
       'RHOZ'      : c10['RHOZ'],
       'PEFZ'      : c10['PEFZ']}

d11  = {'DEPTH'    : c11['TDEP']*0.00254,
       'AT10'      : c11['AT10'],
       'AT20'      : c11['AT20'],
       'AT30'      : c11['AT30'],
       'AT60'      : c11['AT60'],
       'AT90'      : c11['AT90']}

d12  = {'DEPTH'    : c12['TDEP']*0.00254,
       'NPHI'      : c12['NPHI']}

d13  = {'DEPTH'    : c13['TDEP']*0.00254,
       'RHOZ'      : c13['RHOZ'],
       'PEFZ'      : c13['PEFZ']}

d14  = {'DEPTH'    : c14['TDEP']*0.00254,
       'AT10'      : c14['AT10'],
       'AT20'      : c14['AT20'],
       'AT30'      : c14['AT30'],
       'AT60'      : c14['AT60'],
       'AT90'      : c14['AT90']}

d15  = {'DEPTH'    : c15['TDEP']*0.00254,
       'NPHI'      : c15['NPHI']}

d16  = {'DEPTH'    : c16['TDEP']*0.00254,
       'RHOZ'      : c16['RHOZ'],
       'PEFZ'      : c16['PEFZ']}

d17  = {'DEPTH'    : c17['TDEP']*0.00254,
       'AT10'      : c17['AT10'],
       'AT20'      : c17['AT20'],
       'AT30'      : c17['AT30'],
       'AT60'      : c17['AT60'],
       'AT90'      : c17['AT90']}

d18  = {'DEPTH'    : c18['TDEP']*0.00254,
       'NPHI'      : c18['NPHI']}

d19  = {'DEPTH'    : c19['TDEP']*0.00254,
       'RHOZ'      : c19['RHOZ'],
       'PEFZ'      : c19['PEFZ']}

d20  = {'DEPTH'    : c20['TDEP']*0.00254,
       'AT10'      : c20['AT10'],
       'AT20'      : c20['AT20'],
       'AT30'      : c20['AT30'],
       'AT60'      : c20['AT60'],
       'AT90'      : c20['AT90']}

d21  = {'DEPTH'    : c21['TDEP']*0.00254,
       'GR'        : c21['GR']}

d22  = {'DEPTH'    : c22['TDEP']*0.00254,
       'CMFF'      : c22['CMFF'],
       'TCMR'      : c22['TCMR'],
       'CMRP_3MS'  : c22['CMRP_3MS']}

d23  = {'DEPTH'    : c23['TDEP']*0.00254,
       'GR'        : c23['GR']}

d24  = {'DEPTH'    : c24['TDEP']*0.00254,
       'CMFF'      : c24['CMFF'],
       'TCMR'      : c24['TCMR'],
       'CMRP_3MS'  : c24['CMRP_3MS']}

d25  = {'DEPTH'    : c25['TDEP']*0.00254,
       'GR'        : c25['GR']}

d26  = {'DEPTH'    : c26['TDEP']*0.00254,
       'GR'        : c26['GR']}

d27  = {'DEPTH'    : c27['TDEP']*0.00254,
       'GR'        : c27['GR']}

d28  = {'DEPTH'    : c28['TDEP']*0.00254,
       'GR'        : c28['GR']}

d29  = {'DEPTH'    : c29['TDEP']*0.00254,
       'CMFF'      : c29['CMFF'],
       'TCMR'      : c29['TCMR'],
       'CMRP_3MS'  : c29['CMRP_3MS']}

d30  = {'DEPTH'    : c30['TDEP']*0.00254,
       'GR'        : c30['GR']}

d31  = {'DEPTH'    : c31['TDEP']*0.00254,
       'CMFF'      : c31['CMFF'],
       'TCMR'      : c31['TCMR'],
       'CMRP_3MS'  : c31['CMRP_3MS']}

d32  = {'DEPTH'    : c32['TDEP']*0.00254,
       'NPHI'      : c32['NPHI']}

d33  = {'DEPTH'    : c33['TDEP']*0.00254,
       'RHOZ'      : c33['RHOZ'],
       'PEFZ'      : c33['PEFZ']}

d34  = {'DEPTH'    : c34['TDEP']*0.00254,
       'CMFF'      : c34['CMFF'],
       'TCMR'      : c34['TCMR'],
       'CMRP_3MS'  : c34['CMRP_3MS']}

d35  = {'DEPTH'    : c35['TDEP']*0.00254,
       'NPHI'      : c35['NPHI']}

d36  = {'DEPTH'    : c36['TDEP']*0.00254,
       'RHOZ'      : c36['RHOZ'],
       'PEFZ'      : c36['PEFZ']}

d37  = {'DEPTH'    : c37['TDEP']*0.00254,
       'CMFF'      : c37['CMFF'],
       'TCMR'      : c37['TCMR'],
       'CMRP_3MS'  : c37['CMRP_3MS']}

d38  = {'DEPTH'    : c38['TDEP']*0.00254,
       'GR'        : c38['GR']}

d39  = {'DEPTH'    : c39['TDEP']*0.00254,
       'GR'        : c39['GR']}

d40  = {'DEPTH'    : c40['TDEP']*0.00254,
       'GR'        : c40['GR']}

d41  = {'DEPTH'    : c41['TDEP']*0.00254,
       'GR'        : c41['GR']}

d42  = {'DEPTH'    : c42['TDEP']*0.00254,
       'GR'        : c42['GR']}

d43  = {'DEPTH'    : c43['TDEP']*0.00254,
       'GR'        : c43['GR']}

d44  = {'DEPTH'    : c44['TDEP']*0.00254,
       'DTCO'      : c44['DTCO']}

d45  = {'DEPTH'    : c45['TDEP']*0.00254,
       'DTCO'      : c45['DTCO']}

d46  = {'DEPTH'    : c46['TDEP']*0.00254,
       'DTCO'      : c46['DTCO']}

d47  = {'DEPTH'    : c47['TDEP']*0.00254,
       'DTCO'      : c47['DTCO']}

d48  = {'DEPTH'    : c48['TDEP']*0.00254,
       'DTCO'      : c48['DTCO']}

d49  = {'DEPTH'    : c49['TDEP']*0.00254,
       'DTCO'      : c49['DTCO']}

d50  = {'DEPTH'    : c50['TDEP']*0.00254,
       'DTCO'      : c50['DTCO']}

d51  = {'DEPTH'    : c51['TDEP']*0.00254,
       'DTCO'      : c51['DTCO']}

d52  = {'DEPTH'    : c52['TDEP']*0.00254,
       'DTCO'      : c52['DTCO']}

d53  = {'DEPTH'    : c53['TDEP']*0.00254,
       'DTCO'      : c53['DTCO']}

d54  = {'DEPTH'    : c54['TDEP']*0.00254,
       'DTCO'      : c54['DTCO']}

d55  = {'DEPTH'    : c55['TDEP']*0.00254,
       'GR'        : c55['GR']}

# %%
# Create dataframes containing the required well logging curves 
df0 = pd.DataFrame(d0)  
df1 = pd.DataFrame(d1) 
df2 = pd.DataFrame(d2)  
df3 = pd.DataFrame(d3)
df4 = pd.DataFrame(d4)
df5 = pd.DataFrame(d5)
df6 = pd.DataFrame(d6)  
df7 = pd.DataFrame(d7) 
df8 = pd.DataFrame(d8)  
df9 = pd.DataFrame(d9)
df10 = pd.DataFrame(d10)
df11 = pd.DataFrame(d11)
df12 = pd.DataFrame(d12)
df13 = pd.DataFrame(d13)
df14 = pd.DataFrame(d14)
df15 = pd.DataFrame(d15)
df16 = pd.DataFrame(d16)
df17 = pd.DataFrame(d17)
df18 = pd.DataFrame(d18)
df19 = pd.DataFrame(d19)
df20 = pd.DataFrame(d20)
df21 = pd.DataFrame(d21)
df22 = pd.DataFrame(d22)
df23 = pd.DataFrame(d23)
df24 = pd.DataFrame(d24)
df25 = pd.DataFrame(d25)
df26 = pd.DataFrame(d26)
df27 = pd.DataFrame(d27)
df28 = pd.DataFrame(d28)
df29 = pd.DataFrame(d29)
df30 = pd.DataFrame(d30)
df31 = pd.DataFrame(d31)
df32 = pd.DataFrame(d32)
df33 = pd.DataFrame(d33)
df34 = pd.DataFrame(d34)
df35 = pd.DataFrame(d35)
df36 = pd.DataFrame(d36)
df37 = pd.DataFrame(d37)
df38 = pd.DataFrame(d38)
df39 = pd.DataFrame(d39)
df40 = pd.DataFrame(d40)
df41 = pd.DataFrame(d41)
df42 = pd.DataFrame(d42)
df43 = pd.DataFrame(d43)
df44 = pd.DataFrame(d44)
df45 = pd.DataFrame(d45)
df46 = pd.DataFrame(d46)
df47 = pd.DataFrame(d47)
df48 = pd.DataFrame(d48)
df49 = pd.DataFrame(d49)
df50 = pd.DataFrame(d50)
df51 = pd.DataFrame(d51)
df52 = pd.DataFrame(d52)
df53 = pd.DataFrame(d53)
df54 = pd.DataFrame(d54)
df55 = pd.DataFrame(d55)

# %%
# Print the dataframes 
df0, df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13, df14, df15, df16, df17, df18, df19, df20, df21, df22, df23, df24, df25, df26, df27, df28, df29, df30, df31, df32, df33, df34, df35, df36, df37, df38, df39, df40, df41, df42, df43, df44, df45, df46, df47, df48, df49, df50, df51, df52, df53, df54, df55
# Out:
# (            DEPTH          GR
#  0     6340.145020  115.965935
#  1     6340.297363  114.038803
#  2     6340.449707  114.716064
#  3     6340.602051  113.702690
#  4     6340.754395  116.016182
#  ...           ...         ...
#  1316  6540.703125   94.236794
#  1317  6540.855469   94.236794
#  1318  6541.007812   94.236794
#  1319  6541.160645   94.236794
#  1320  6541.312988   94.236794
#
#  [1321 rows x 2 columns],
#              DEPTH        AT10        AT20        AT30        AT60        AT90
#  0     6340.068848    3.536455    3.552292    3.578175    3.546901    3.550082
#  1     6340.145020    3.491768    3.531816    3.544103    3.523875    3.535878
#  2     6340.221191    3.463664    3.516852    3.521938    3.509453    3.503694
#  3     6340.297363    3.442253    3.495166    3.493145    3.494104    3.495173
#  4     6340.373535    3.413858    3.467846    3.456501    3.465535    3.476827
#  ...           ...         ...         ...         ...         ...         ...
# ...

# %% [markdown]
# <span style='color:brown'> <span style="font-size:19px;"> **STEP 3: Data Pre-Processing**

# %%
# Remove "-999.250000" from each dataframe. It does not make any sense.

df0.drop(df0.loc[df0['GR']==-999.25].index, inplace=True)
        
df1.drop(df1.loc[df1['AT10']==-999.25].index, inplace=True)
df1.drop(df1.loc[df1['AT20']==-999.25].index, inplace=True)
df1.drop(df1.loc[df1['AT30']==-999.25].index, inplace=True)
df1.drop(df1.loc[df1['AT60']==-999.25].index, inplace=True)
df1.drop(df1.loc[df1['AT90']==-999.25].index, inplace=True)

df2.drop(df2.loc[df2['GR']==-999.25].index, inplace=True)
        
df3.drop(df3.loc[df3['AT10']==-999.25].index, inplace=True)
df3.drop(df3.loc[df3['AT20']==-999.25].index, inplace=True)
df3.drop(df3.loc[df3['AT30']==-999.25].index, inplace=True)
df3.drop(df3.loc[df3['AT60']==-999.25].index, inplace=True)
df3.drop(df3.loc[df3['AT90']==-999.25].index, inplace=True)

df4.drop(df4.loc[df4['GR']==-999.25].index, inplace=True)
        
df5.drop(df5.loc[df5['AT10']==-999.25].index, inplace=True)
df5.drop(df5.loc[df5['AT20']==-999.25].index, inplace=True)
df5.drop(df5.loc[df5['AT30']==-999.25].index, inplace=True)
df5.drop(df5.loc[df5['AT60']==-999.25].index, inplace=True)
df5.drop(df5.loc[df5['AT90']==-999.25].index, inplace=True)

df6.drop(df6.loc[df6['NPHI']==-999.25].index, inplace=True)
        
df7.drop(df7.loc[df7['RHOZ']==-999.25].index, inplace=True)
df7.drop(df7.loc[df7['PEFZ']==-999.25].index, inplace=True)

df8.drop(df8.loc[df8['AT10']==-999.25].index, inplace=True)
df8.drop(df8.loc[df8['AT20']==-999.25].index, inplace=True)
df8.drop(df8.loc[df8['AT30']==-999.25].index, inplace=True)
df8.drop(df8.loc[df8['AT60']==-999.25].index, inplace=True)
df8.drop(df8.loc[df8['AT90']==-999.25].index, inplace=True)

df9.drop(df9.loc[df9['NPHI']==-999.25].index, inplace=True)
        
df10.drop(df10.loc[df10['RHOZ']==-999.25].index, inplace=True)
df10.drop(df10.loc[df10['PEFZ']==-999.25].index, inplace=True)

df11.drop(df11.loc[df11['AT10']==-999.25].index, inplace=True)
df11.drop(df11.loc[df11['AT20']==-999.25].index, inplace=True)
df11.drop(df11.loc[df11['AT30']==-999.25].index, inplace=True)
df11.drop(df11.loc[df11['AT60']==-999.25].index, inplace=True)
df11.drop(df11.loc[df11['AT90']==-999.25].index, inplace=True)

df12.drop(df12.loc[df12['NPHI']==-999.25].index, inplace=True)
        
df13.drop(df13.loc[df13['RHOZ']==-999.25].index, inplace=True)
df13.drop(df13.loc[df13['PEFZ']==-999.25].index, inplace=True)

df14.drop(df14.loc[df14['AT10']==-999.25].index, inplace=True)
df14.drop(df14.loc[df14['AT20']==-999.25].index, inplace=True)
df14.drop(df14.loc[df14['AT30']==-999.25].index, inplace=True)
df14.drop(df14.loc[df14['AT60']==-999.25].index, inplace=True)
df14.drop(df14.loc[df14['AT90']==-999.25].index, inplace=True)

df15.drop(df15.loc[df15['NPHI']==-999.25].index, inplace=True)
        
df16.drop(df16.loc[df16['RHOZ']==-999.25].index, inplace=True)
df16.drop(df16.loc[df16['PEFZ']==-999.25].index, inplace=True)

df17.drop(df17.loc[df17['AT10']==-999.25].index, inplace=True)
df17.drop(df17.loc[df17['AT20']==-999.25].index, inplace=True)
df17.drop(df17.loc[df17['AT30']==-999.25].index, inplace=True)
df17.drop(df17.loc[df17['AT60']==-999.25].index, inplace=True)
df17.drop(df17.loc[df17['AT90']==-999.25].index, inplace=True)

df18.drop(df18.loc[df18['NPHI']==-999.25].index, inplace=True)
        
df19.drop(df19.loc[df19['RHOZ']==-999.25].index, inplace=True)
df19.drop(df19.loc[df19['PEFZ']==-999.25].index, inplace=True)

df20.drop(df20.loc[df20['AT10']==-999.25].index, inplace=True)
df20.drop(df20.loc[df20['AT20']==-999.25].index, inplace=True)
df20.drop(df20.loc[df20['AT30']==-999.25].index, inplace=True)
df20.drop(df20.loc[df20['AT60']==-999.25].index, inplace=True)
df20.drop(df20.loc[df20['AT90']==-999.25].index, inplace=True)
      
df21.drop(df21.loc[df21['GR']==-999.25].index, inplace=True)

df22.drop(df22.loc[df22['CMFF']==-999.25].index, inplace=True)
df22.drop(df22.loc[df22['TCMR']==-999.25].index, inplace=True)
df22.drop(df22.loc[df22['CMRP_3MS']==-999.25].index, inplace=True)

df23.drop(df23.loc[df23['GR']==-999.25].index, inplace=True)

df24.drop(df24.loc[df24['CMFF']==-999.25].index, inplace=True)
df24.drop(df24.loc[df24['TCMR']==-999.25].index, inplace=True)
df24.drop(df24.loc[df24['CMRP_3MS']==-999.25].index, inplace=True)

df25.drop(df25.loc[df25['GR']==-999.25].index, inplace=True)
df26.drop(df26.loc[df26['GR']==-999.25].index, inplace=True)
df27.drop(df27.loc[df27['GR']==-999.25].index, inplace=True)

df28.drop(df28.loc[df28['GR']==-999.25].index, inplace=True)

df29.drop(df29.loc[df29['CMFF']==-999.25].index, inplace=True)
df29.drop(df29.loc[df29['TCMR']==-999.25].index, inplace=True)
df29.drop(df29.loc[df29['CMRP_3MS']==-999.25].index, inplace=True)

df30.drop(df30.loc[df30['GR']==-999.25].index, inplace=True)

df31.drop(df31.loc[df31['CMFF']==-999.25].index, inplace=True)
df31.drop(df31.loc[df31['TCMR']==-999.25].index, inplace=True)
df31.drop(df31.loc[df31['CMRP_3MS']==-999.25].index, inplace=True)

df32.drop(df32.loc[df32['NPHI']==-999.25].index, inplace=True)

df33.drop(df33.loc[df33['RHOZ']==-999.25].index, inplace=True)
df33.drop(df33.loc[df33['PEFZ']==-999.25].index, inplace=True)

df34.drop(df34.loc[df34['CMFF']==-999.25].index, inplace=True)
df34.drop(df34.loc[df34['TCMR']==-999.25].index, inplace=True)
df34.drop(df34.loc[df34['CMRP_3MS']==-999.25].index, inplace=True)

df35.drop(df35.loc[df35['NPHI']==-999.25].index, inplace=True)

df36.drop(df36.loc[df36['RHOZ']==-999.25].index, inplace=True)
df36.drop(df36.loc[df36['PEFZ']==-999.25].index, inplace=True)

df37.drop(df37.loc[df37['CMFF']==-999.25].index, inplace=True)
df37.drop(df37.loc[df37['TCMR']==-999.25].index, inplace=True)
df37.drop(df37.loc[df37['CMRP_3MS']==-999.25].index, inplace=True)

df38.drop(df38.loc[df38['GR']==-999.25].index, inplace=True)
df39.drop(df39.loc[df39['GR']==-999.25].index, inplace=True)
df40.drop(df40.loc[df40['GR']==-999.25].index, inplace=True)
df41.drop(df41.loc[df41['GR']==-999.25].index, inplace=True)
df42.drop(df42.loc[df42['GR']==-999.25].index, inplace=True)
df43.drop(df43.loc[df43['GR']==-999.25].index, inplace=True)

df44.drop(df44.loc[df44['DTCO']==-999.25].index, inplace=True)
df45.drop(df45.loc[df45['DTCO']==-999.25].index, inplace=True)
df46.drop(df46.loc[df46['DTCO'] == -999.25].index, inplace=True)
df47.drop(df47.loc[df47['DTCO'] == -999.25].index, inplace=True)
df48.drop(df48.loc[df48['DTCO'] == -999.25].index, inplace=True)
df49.drop(df49.loc[df49['DTCO'] == -999.25].index, inplace=True)
df50.drop(df50.loc[df50['DTCO'] == -999.25].index, inplace=True)
df51.drop(df51.loc[df51['DTCO'] == -999.25].index, inplace=True)
df52.drop(df52.loc[df52['DTCO'] == -999.25].index, inplace=True)
df53.drop(df53.loc[df53['DTCO'] == -999.25].index, inplace=True)
df54.drop(df54.loc[df54['DTCO'] == -999.25].index, inplace=True)

df55.drop(df55.loc[df55['GR']==-999.25].index, inplace=True)

# %%
# Reset the Index of each dataframe 
# (drop=True) means that the current Index will be replaced entirely 
"""df0 = df0.reset_index(drop=True)
df1 = df1.reset_index(drop=True)
df2 = df2.reset_index(drop=True)
df3 = df3.reset_index(drop=True) 
df4 = df4.reset_index(drop=True) 
df5 = df5.reset_index(drop=True)
df6 = df6.reset_index(drop=True)
df7 = df7.reset_index(drop=True) 
df8 = df8.reset_index(drop=True) 
df9 = df9.reset_index(drop=True)
df10 = df10.reset_index(drop=True) 
df11 = df11.reset_index(drop=True) 
df12 = df12.reset_index(drop=True)"""
# Out:
# 'df0 = df0.reset_index(drop=True)\ndf1 = df1.reset_index(drop=True)\ndf2 = df2.reset_index(drop=True)\ndf3 = df3.reset_index(drop=True) \ndf4 = df4.reset_index(drop=True) \ndf5 = df5.reset_index(drop=True)\ndf6 = df6.reset_index(drop=True)\ndf7 = df7.reset_index(drop=True) \ndf8 = df8.reset_index(drop=True) \ndf9 = df9.reset_index(drop=True)\ndf10 = df10.reset_index(drop=True) \ndf11 = df11.reset_index(drop=True) \ndf12 = df12.reset_index(drop=True)'

# %%
#df0  = df0.iloc[::-1]
#df1  = df1.iloc[::-1]
df2  = df2.iloc[::-1]
df3  = df3.iloc[::-1]
#df4  = df4.iloc[::-1]
#df5  = df5.iloc[::-1]
df6  = df6.iloc[::-1]
df7  = df7.iloc[::-1]
df8  = df8.iloc[::-1]
df9  = df9.iloc[::-1]
df10  = df10.iloc[::-1]
df11  = df11.iloc[::-1]
#df12  = df12.iloc[::-1]
#df13 = df13.iloc[::-1]
#df14 = df14.iloc[::-1]
df15 = df15.iloc[::-1]
df16 = df16.iloc[::-1]
df17 = df17.iloc[::-1]
df18 = df18.iloc[::-1]
df19 = df19.iloc[::-1]
df20 = df20.iloc[::-1]
df21 = df21.iloc[::-1]
df22 = df22.iloc[::-1]
df23 = df23.iloc[::-1]
df24 = df24.iloc[::-1]
#df25 = df25.iloc[::-1]
#df26 = df26.iloc[::-1]
#df27 = df27.iloc[::-1]
df28 = df28.iloc[::-1]
df29 = df29.iloc[::-1]
df30 = df30.iloc[::-1]
df31 = df31.iloc[::-1]
df32 = df32.iloc[::-1]
df33 = df33.iloc[::-1]
df34 = df34.iloc[::-1]
df35 = df35.iloc[::-1]
df36 = df36.iloc[::-1]
df37 = df37.iloc[::-1]
df38 = df38.iloc[::-1]
#df39 = df39.iloc[::-1]
#df40 = df40.iloc[::-1]
df41 = df41.iloc[::-1]
df42 = df42.iloc[::-1]
df43 = df43.iloc[::-1]
#df44 = df44.iloc[::-1]
#df45 = df45.iloc[::-1]
df46 = df46.iloc[::-1]
df47 = df47.iloc[::-1]
#df48 = df48.iloc[::-1]
df49 = df49.iloc[::-1]
#df50 = df50.iloc[::-1]
df51 = df51.iloc[::-1]
df52 = df52.iloc[::-1]
df53 = df53.iloc[::-1]
df54 = df54.iloc[::-1]
df55 = df55.iloc[::-1]

# %%
df0, df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13, df14, df15, df16, df17, df18, df19, df20, df21, df22, df23, df24, df25, df26, df27, df28, df29, df30, df31, df32, df33, df34, df35, df36, df37, df38, df39, df40, df41, df42, df43, df44, df45, df46, df47, df48, df49, df50, df51, df52, df53, df54, df55
# Out:
# (            DEPTH          GR
#  0     6340.145020  115.965935
#  1     6340.297363  114.038803
#  2     6340.449707  114.716064
#  3     6340.602051  113.702690
#  4     6340.754395  116.016182
#  ...           ...         ...
#  1316  6540.703125   94.236794
#  1317  6540.855469   94.236794
#  1318  6541.007812   94.236794
#  1319  6541.160645   94.236794
#  1320  6541.312988   94.236794
#
#  [1321 rows x 2 columns],
#              DEPTH      AT10      AT20      AT30      AT60      AT90
#  0     6340.068848  3.536455  3.552292  3.578175  3.546901  3.550082
#  1     6340.145020  3.491768  3.531816  3.544103  3.523875  3.535878
#  2     6340.221191  3.463664  3.516852  3.521938  3.509453  3.503694
#  3     6340.297363  3.442253  3.495166  3.493145  3.494104  3.495173
#  4     6340.373535  3.413858  3.467846  3.456501  3.465535  3.476827
#  ...           ...       ...       ...       ...       ...       ...
#  2606  6538.645996  1.330072  1.303488  1.348753  1.692036  2.147870
# ...

# %%
# Reset the Index of each dataframe 
df0  = df0.reset_index(drop=True) 
df1  = df1.reset_index(drop=True)
df2  = df2.reset_index(drop=True)
df3  = df3.reset_index(drop=True)
df4  = df4.reset_index(drop=True)
df5  = df5.reset_index(drop=True)
df6  = df6.reset_index(drop=True) 
df7  = df7.reset_index(drop=True)
df8  = df8.reset_index(drop=True)
df9  = df9.reset_index(drop=True)
df10  = df10.reset_index(drop=True)
df11  = df11.reset_index(drop=True)
df12  = df12.reset_index(drop=True)
df13  = df13.reset_index(drop=True)
df14  = df14.reset_index(drop=True)
df15  = df15.reset_index(drop=True)
df16  = df16.reset_index(drop=True)
df17  = df17.reset_index(drop=True)
df18  = df18.reset_index(drop=True)
df19  = df19.reset_index(drop=True)
df20  = df20.reset_index(drop=True)
df21  = df21.reset_index(drop=True)
df22  = df22.reset_index(drop=True)
df23  = df23.reset_index(drop=True)
df24  = df24.reset_index(drop=True)
df25  = df25.reset_index(drop=True)
df26  = df26.reset_index(drop=True)
df27  = df27.reset_index(drop=True)
df28  = df28.reset_index(drop=True)
df29  = df29.reset_index(drop=True)
df30  = df30.reset_index(drop=True)
df31  = df31.reset_index(drop=True)
df32  = df32.reset_index(drop=True)
df33  = df33.reset_index(drop=True)
df34  = df34.reset_index(drop=True)
df35  = df35.reset_index(drop=True)
df36  = df36.reset_index(drop=True)
df37  = df37.reset_index(drop=True)
df38  = df38.reset_index(drop=True)
df39  = df39.reset_index(drop=True)
df40  = df40.reset_index(drop=True)
df41  = df41.reset_index(drop=True)
df42  = df42.reset_index(drop=True)
df43  = df43.reset_index(drop=True)
df44  = df44.reset_index(drop=True)
df45  = df45.reset_index(drop=True)
df46  = df46.reset_index(drop=True)
df47  = df47.reset_index(drop=True)
df48  = df48.reset_index(drop=True)
df49  = df49.reset_index(drop=True)
df50  = df50.reset_index(drop=True)
df51  = df51.reset_index(drop=True)
df52  = df52.reset_index(drop=True)
df53  = df53.reset_index(drop=True)
df54  = df54.reset_index(drop=True)
df55  = df55.reset_index(drop=True)

# %%
# Initialize an empty list to store dataframes
dfs = []

# Create dataframes df0 to df55 and add them to the list
for i in range(56):
    df_name = f'df{i}'
    df = locals()[df_name]
    dfs.append(df)

# Iterate through each DataFrame in the list
for i, df in enumerate(dfs):
    # Reset the index
    df.reset_index(drop=True, inplace=True)

    # Print the new dataframe
    print(f'df{i}:')
    print(df)
    print('\n')

    # Remove NaN values in place
    df.dropna(inplace=True)
# Out:
# df0:
#             DEPTH          GR
# 0     6340.145020  115.965935
# 1     6340.297363  114.038803
# 2     6340.449707  114.716064
# 3     6340.602051  113.702690
# 4     6340.754395  116.016182
# ...           ...         ...
# 1316  6540.703125   94.236794
# 1317  6540.855469   94.236794
# 1318  6541.007812   94.236794
# 1319  6541.160645   94.236794
# 1320  6541.312988   94.236794
#
# [1321 rows x 2 columns]
#
#
# df1:
#             DEPTH      AT10      AT20      AT30      AT60      AT90
# 0     6340.068848  3.536455  3.552292  3.578175  3.546901  3.550082
# 1     6340.145020  3.491768  3.531816  3.544103  3.523875  3.535878
# 2     6340.221191  3.463664  3.516852  3.521938  3.509453  3.503694
# 3     6340.297363  3.442253  3.495166  3.493145  3.494104  3.495173
# 4     6340.373535  3.413858  3.467846  3.456501  3.465535  3.476827
# ...           ...       ...       ...       ...       ...       ...
# 2606  6538.645996  1.330072  1.303488  1.348753  1.692036  2.147870
# ...

# %%
#df0.describe(), df1.describe(), df2.describe(), df3.describe(), df4.describe(), df5.describe(), df6.describe(), df7.describe(), df8.describe(), df9.describe(), df10.describe(), df11.describe(), df12.describe()

# %% [markdown]
# <span style='color:brown'> <span style="font-size:19px;"> **STEP 4: Create dataframe of each well-log data [unique dataframe] to plot them versus depth**

# %% [markdown]
# **GR log**
# 0
# 2
# 4
# 21
# 23
# 25
# 26
# 27
# 28
# 30
# 38
# 39
# 40
# 41
# 42
# 43
# 55

# %%
df0_GR = df0
df2_GR = df2
df4_GR = df4
df21_GR = df21
df23_GR = df23
df25_GR = df25
df26_GR = df26
df27_GR = df27
df28_GR = df28
df30_GR = df30
df38_GR = df38
df39_GR = df39
df40_GR = df40
df41_GR = df41
df42_GR = df42
df43_GR = df43
df55_GR = df55
#df0_GR, df2_GR, df4_GR, df21_GR, df23_GR, df25_GR, df26_GR, df27_GR, df28_GR, df30_GR, df38_GR, df39_GR, df40_GR, df41_GR, df42_GR, df43_GR, df55_GR

# %%
#df55_GR, df23_GR, df26_GR, df0_GR

# %%
df23_GR = df23
df23_GR = df23_GR.drop(df23_GR.index[:517])  
#df23_GR

# %%
df26_GR = df26
df26_GR = df26_GR.drop(df26_GR.index[:286])  
#df26_GR

# %%
df55_GR, df23_GR, df26_GR, df0_GR
# Out:
# (           DEPTH         GR
#  0    5953.658203  13.533829
#  1    5953.811035  13.533829
#  2    5953.963379  13.533829
#  3    5954.115723  13.533829
#  4    5954.268066  13.533829
#  ..           ...        ...
#  880  6087.770508  25.617657
#  881  6087.922852  25.617657
#  882  6088.075195  25.617657
#  883  6088.227539  25.617657
#  884  6088.379883  25.617657
#
#  [885 rows x 2 columns],
#              DEPTH         GR
#  517   6088.837402  31.092636
#  518   6088.989746  31.747841
#  519   6089.142090  28.620102
#  520   6089.294434  26.368811
#  521   6089.446777  26.890047
#  ...           ...        ...
#  1325  6211.976562  18.753937
#  1326  6212.128906  18.753937
#  1327  6212.281250  18.753937
#  1328  6212.433594  18.753937
#  1329  6212.585938  18.753937
#
#  [813 rows x 2 columns],
#              DEPTH          GR
#  286   6212.890625   33.239017
#  287   6213.043457   33.868832
#  288   6213.195801   32.115585
#  289   6213.348145   31.215586
# ...

# %%
df_GR = pd.concat([df55_GR, df23_GR, df26_GR, df0_GR], axis = 0, ignore_index = True)
df_GR
# Out:
#             DEPTH         GR
# 0     5953.658203  13.533829
# 1     5953.811035  13.533829
# 2     5953.963379  13.533829
# 3     5954.115723  13.533829
# 4     5954.268066  13.533829
# ...           ...        ...
# 3839  6540.703125  94.236794
# 3840  6540.855469  94.236794
# 3841  6541.007812  94.236794
# 3842  6541.160645  94.236794
# 3843  6541.312988  94.236794
#
# [3844 rows x 2 columns]

# %% [markdown]
# **Nuetron Porosity Log**
# **NPHI:**
#
# df6, df9, df12, df15, df18, df32, df35

# %%
df12_NPHI = df12
df18_NPHI = df18  
df32_NPHI = df32

# %%
#df18_NPHI = df18  
df18_NPHI = df18_NPHI.drop(df18_NPHI.index[:340])  
df18_NPHI
# Out:
#             DEPTH      NPHI
# 340   6209.842773  0.076517
# 341   6209.995117  0.076743
# 342   6210.147461  0.068507
# 343   6210.299805  0.060960
# 344   6210.452637  0.069695
# ...           ...       ...
# 1587  6399.885742  0.252535
# 1588  6400.038086  0.252535
# 1589  6400.190430  0.252535
# 1590  6400.342773  0.252535
# 1591  6400.495117  0.252535
#
# [1252 rows x 2 columns]

# %%
df32_NPHI = df32
df32_NPHI = df32_NPHI.drop(df32_NPHI.index[:268]) 
df32_NPHI
# Out:
#             DEPTH      NPHI
# 268   6400.952637  0.248644
# 269   6401.104980  0.249506
# 270   6401.257324  0.256705
# 271   6401.409668  0.255806
# 272   6401.562012  0.254279
# ...           ...       ...
# 1207  6544.056152  0.317413
# 1208  6544.208496  0.317413
# 1209  6544.360840  0.317413
# 1210  6544.513184  0.317413
# 1211  6544.665527  0.317413
#
# [944 rows x 2 columns]

# %%
df12_NPHI, df18_NPHI, df32_NPHI
# Out:
# (            DEPTH      NPHI
#  0     5565.038574 -0.015978
#  1     5565.190918 -0.016029
#  2     5565.343262 -0.013769
#  3     5565.495605 -0.012476
#  4     5565.647949 -0.011727
#  ...           ...       ...
#  4222  6208.471191  0.182646
#  4223  6208.623535  0.182646
#  4224  6208.775879  0.182646
#  4225  6208.928223  0.182646
#  4226  6209.081055  0.182646
#
#  [4227 rows x 2 columns],
#              DEPTH      NPHI
#  340   6209.842773  0.076517
#  341   6209.995117  0.076743
#  342   6210.147461  0.068507
#  343   6210.299805  0.060960
#  344   6210.452637  0.069695
#  ...           ...       ...
#  1587  6399.885742  0.252535
#  1588  6400.038086  0.252535
#  1589  6400.190430  0.252535
#  1590  6400.342773  0.252535
#  1591  6400.495117  0.252535
#
#  [1252 rows x 2 columns],
#              DEPTH      NPHI
#  268   6400.952637  0.248644
#  269   6401.104980  0.249506
#  270   6401.257324  0.256705
#  271   6401.409668  0.255806
#  272   6401.562012  0.254279
# ...

# %%
df_NPHI = pd.concat([df12_NPHI, df18_NPHI, df32_NPHI], axis = 0, ignore_index = True)
df_NPHI
# Out:
#             DEPTH      NPHI
# 0     5565.038574 -0.015978
# 1     5565.190918 -0.016029
# 2     5565.343262 -0.013769
# 3     5565.495605 -0.012476
# 4     5565.647949 -0.011727
# ...           ...       ...
# 6418  6544.056152  0.317413
# 6419  6544.208496  0.317413
# 6420  6544.360840  0.317413
# 6421  6544.513184  0.317413
# 6422  6544.665527  0.317413
#
# [6423 rows x 2 columns]

# %% [markdown]
# **Density Log**
#
# **RHOZ:**
# * df2 ==> 5305.094727 - 5502.960938
# * df8 ==> 5719.927734 - 5938.215332
# * df11 ==> 5797.854980 - 5317.439453
#
#
# df7
# df10
# df13
# df16
# df19
# df33
# df36

# %%
df13_RHOZ = df13.drop(columns=["PEFZ"])
df19_RHOZ = df19.drop(columns=["PEFZ"])
df33_RHOZ = df33.drop(columns=["PEFZ"])
#df13_RHOZ, df19_RHOZ, df33_RHOZ

# %%
df19_RHOZ = df19.drop(columns=["PEFZ"])
df19_RHOZ = df19_RHOZ.drop(df19_RHOZ.index[:880])  
#df19_RHOZ

# %%
df33_RHOZ = df33.drop(columns=["PEFZ"])
df33_RHOZ = df33_RHOZ.drop(df33_RHOZ.index[:635])  
#df33_RHOZ

# %%
df13_RHOZ, df19_RHOZ, df33_RHOZ
# Out:
# (             DEPTH      RHOZ
#  0      5565.038574  2.819694
#  1      5565.089355  2.840995
#  2      5565.140137  2.866344
#  3      5565.190918  2.895582
#  4      5565.241699  2.921495
#  ...            ...       ...
#  12543  6202.222656  2.248011
#  12544  6202.273438  2.248011
#  12545  6202.324219  2.248011
#  12546  6202.375000  2.248011
#  12547  6202.426270  2.248011
#
#  [12548 rows x 2 columns],
#              DEPTH      RHOZ
#  880   6202.730957  2.483472
#  881   6202.781738  2.502849
#  882   6202.832520  2.524726
#  883   6202.883301  2.545233
#  884   6202.934082  2.553446
#  ...           ...       ...
#  4603  6391.859375  2.523820
#  4604  6391.910156  2.528141
#  4605  6391.960938  2.530455
#  4606  6392.011719  2.531634
#  4607  6392.062500  2.534153
#
#  [3728 rows x 2 columns],
#              DEPTH      RHOZ
#  635   6392.265625  2.561998
#  636   6392.316406  2.561698
#  637   6392.367188  2.560736
#  638   6392.417969  2.559168
# ...

# %%
df_RHOZ = pd.concat([df13_RHOZ, df19_RHOZ, df33_RHOZ], axis = 0, ignore_index = True)
df_RHOZ
# Out:
#              DEPTH      RHOZ
# 0      5565.038574  2.819694
# 1      5565.089355  2.840995
# 2      5565.140137  2.866344
# 3      5565.190918  2.895582
# 4      5565.241699  2.921495
# ...            ...       ...
# 19097  6535.572266  2.242365
# 19098  6535.623047  2.247346
# 19099  6535.673828  2.253108
# 19100  6535.724609  2.260017
# 19101  6535.775879  2.268404
#
# [19102 rows x 2 columns]

# %% [markdown]
# **Photo Electeric Log**
#
# **PEFZ:**
# * df2 ==> 5305.094727 - 5502.960938
# * df8 ==> 5719.927734 - 5938.215332
# * df11 ==> 5797.854980 - 5317.439453

# %%
df13_PEFZ = df13.drop(columns=["RHOZ"])
df19_PEFZ = df19.drop(columns=["RHOZ"])
df33_PEFZ = df33.drop(columns=["RHOZ"])
#df13_PEFZ, df19_PEFZ, df33_PEFZ

# %%
df19_PEFZ = df19.drop(columns=["RHOZ"])
df19_PEFZ = df19_PEFZ.drop(df19_PEFZ.index[:880])  
#df19_PEFZ

# %%
df33_PEFZ = df33.drop(columns=["RHOZ"])
df33_PEFZ = df33_PEFZ.drop(df33_PEFZ.index[:635])  
#df33_PEFZ

# %%
df13_PEFZ, df19_PEFZ, df33_PEFZ
# Out:
# (             DEPTH      PEFZ
#  0      5565.038574  9.982440
#  1      5565.089355  9.979645
#  2      5565.140137  9.974916
#  3      5565.190918  9.966947
#  4      5565.241699  9.955168
#  ...            ...       ...
#  12543  6202.222656  1.379672
#  12544  6202.273438  1.379672
#  12545  6202.324219  1.379672
#  12546  6202.375000  1.379672
#  12547  6202.426270  1.379672
#
#  [12548 rows x 2 columns],
#              DEPTH      PEFZ
#  880   6202.730957  7.527485
#  881   6202.781738  7.544818
#  882   6202.832520  7.492095
#  883   6202.883301  7.349424
#  884   6202.934082  7.176270
#  ...           ...       ...
#  4603  6391.859375  5.368292
#  4604  6391.910156  5.184343
#  4605  6391.960938  4.996349
#  4606  6392.011719  4.801659
#  4607  6392.062500  4.598649
#
#  [3728 rows x 2 columns],
#              DEPTH      PEFZ
#  635   6392.265625  4.147651
#  636   6392.316406  4.149116
#  637   6392.367188  4.160486
#  638   6392.417969  4.178549
# ...

# %%
df_PEFZ = pd.concat([df13_PEFZ, df19_PEFZ, df33_PEFZ], axis = 0, ignore_index = True)
df_PEFZ
# Out:
#              DEPTH      PEFZ
# 0      5565.038574  9.982440
# 1      5565.089355  9.979645
# 2      5565.140137  9.974916
# 3      5565.190918  9.966947
# 4      5565.241699  9.955168
# ...            ...       ...
# 19097  6535.572266  4.441442
# 19098  6535.623047  4.349269
# 19099  6535.673828  4.251187
# 19100  6535.724609  4.148312
# 19101  6535.775879  4.039859
#
# [19102 rows x 2 columns]

# %% [markdown]
# **Compressional Slowness Log**
#
# **DTCO:**
# * df7 ==> 5719.876953 - 5938.875488
# * df10 ==> 5317.388672 - 5799.125000

# %%
df44_DTCO = df44
df45_DTCO = df45
df46_DTCO = df46
df47_DTCO = df47
df48_DTCO = df48
df49_DTCO = df49
df50_DTCO = df50
df51_DTCO = df51
df52_DTCO = df52
df53_DTCO = df53
df54_DTCO = df54
# df44_DTCO, df45_DTCO, df46_DTCO, df47_DTCO, df48_DTCO, df49_DTCO, df50_DTCO, df51_DTCO, df52_DTCO, df53_DTCO, df54_DTCO

# %%
#df54_DTCO, df49_DTCO, df46_DTCO

# %%
df49_DTCO = df49
df49_DTCO = df49_DTCO.drop(df49_DTCO.index[:185]) 
#df49_DTCO

# %%
df46_DTCO = df46
df46_DTCO = df46_DTCO.drop(df46_DTCO.index[:400]) 
# df46_DTCO

# %%
df54_DTCO, df49_DTCO, df46_DTCO
# Out:
# (            DEPTH       DTCO
#  0     6010.046387  69.571129
#  1     6010.198730  68.377068
#  2     6010.351074  67.587067
#  3     6010.503418  67.038910
#  4     6010.656250  68.358742
#  ...           ...        ...
#  1150  6185.306641  59.923477
#  1151  6185.458984  59.961571
#  1152  6185.611328  59.968513
#  1153  6185.763672  59.965927
#  1154  6185.916016  59.964993
#
#  [1155 rows x 2 columns],
#              DEPTH       DTCO
#  185   6186.220703  73.267159
#  186   6186.373047  68.126854
#  187   6186.525879  63.730976
#  188   6186.678223  62.718021
#  189   6186.830566  72.512878
#  ...           ...        ...
#  1425  6375.196777  67.705589
#  1426  6375.349121  67.770363
#  1427  6375.501465  67.824844
#  1428  6375.653809  67.841896
#  1429  6375.806641  67.903923
#
#  [1245 rows x 2 columns],
#              DEPTH       DTCO
#  400   6376.111328  71.705963
#  401   6376.263672  71.256233
#  402   6376.416016  70.765877
#  403   6376.568359  70.959389
# ...

# %%
df_DTCO = pd.concat([df54_DTCO, df49_DTCO, df46_DTCO], axis = 0, ignore_index = True)
df_DTCO
# Out:
#             DEPTH       DTCO
# 0     6010.046387  69.571129
# 1     6010.198730  68.377068
# 2     6010.351074  67.587067
# 3     6010.503418  67.038910
# 4     6010.656250  68.358742
# ...           ...        ...
# 3364  6523.024902  84.938866
# 3365  6523.177246  84.962334
# 3366  6523.329590  84.959373
# 3367  6523.481934  84.942581
# 3368  6523.634277  85.612190
#
# [3369 rows x 2 columns]

# %% [markdown]
# **AT**
#
# **AT:**
# * df1 ==> 5305.120117 - 5504.230957
# * df5 ==>  5453.405273 - 5794.552734 (no)
# * df9 ==> 5719.953125 - 5939.485352
# * df12 ==> 5317.464844 - 5799.125000

# %%
df1_AT = df1
df3_AT = df3
df5_AT = df5
df8_AT = df8
df11_AT = df11
df14_AT = df14
df17_AT = df17
df20_AT = df20

# %%
df20_AT = df20
df20_AT = df20_AT.drop(df20_AT.index[:644]) 
#df20_AT

# %%
df1_AT = df1
df1_AT = df1_AT.drop(df1_AT.index[:770]) 
#df1_AT

# %%
df14_AT, df20_AT, df1_AT
# Out:
# (            DEPTH         AT10        AT20         AT30        AT60  \
#  0     5565.038574  1950.000000    1.193704  1950.000000   64.710999
#  1     5565.114746  1950.000000    1.210524  1950.000000   54.256584
#  2     5565.190918  1950.000000    1.231891  1950.000000   51.306969
#  3     5565.267090  1950.000000    1.257184  1950.000000   51.200054
#  4     5565.343262  1950.000000    1.285751  1950.000000   48.752720
#  ...           ...          ...         ...          ...         ...
#  8416  6206.337402    70.893158  329.531403   450.044830  783.491577
#  8417  6206.414062    77.499184  255.200439   329.263824  510.219574
#  8418  6206.490234    69.377136  238.025009   184.895233  333.992523
#  8419  6206.566406    63.094437  185.354767   215.677490  414.119812
#  8420  6206.642578    65.329552  149.829941   170.212479  295.131989
#
#              AT90
#  0     110.398376
#  1     105.186035
#  2      99.201767
#  3      91.750572
#  4      79.979645
#  ...          ...
# ...

# %%
df_AT = pd.concat([df14_AT, df20_AT, df1_AT], axis = 0, ignore_index = True)
df_AT
# Out:
#              DEPTH         AT10      AT20         AT30       AT60        AT90
# 0      5565.038574  1950.000000  1.193704  1950.000000  64.710999  110.398376
# 1      5565.114746  1950.000000  1.210524  1950.000000  54.256584  105.186035
# 2      5565.190918  1950.000000  1.231891  1950.000000  51.306969   99.201767
# 3      5565.267090  1950.000000  1.257184  1950.000000  51.200054   91.750572
# 4      5565.343262  1950.000000  1.285751  1950.000000  48.752720   79.979645
# ...            ...          ...       ...          ...        ...         ...
# 12764  6538.645996     1.330072  1.303488     1.348753   1.692036    2.147870
# 12765  6538.722168     1.316746  1.283108     1.330109   1.658345    2.159613
# 12766  6538.798340     1.288868  1.298612     1.348408   1.708738    2.241369
# 12767  6538.874512     1.289152  1.316085     1.353374   1.707678    2.267577
# 12768  6538.950684     1.299871  1.323702     1.342931   1.702814    2.263208
#
# [12769 rows x 6 columns]

# %% [markdown]
# **NMR**

# %%
df22_NMR= df22
df24_NMR = df24
df29_NMR = df29
df31_NMR = df31
df34_NMR = df34
df37_NMR = df37
# df22_NMR, df24_NMR, df29_NMR, df31_NMR, df34_NMR, df37_NMR

# %%
#df24_NMR, df31_NMR, df34_NMR

# %%
df31_NMR = df31
df31_NMR = df31_NMR.drop(df31_NMR.index[:280]) 
#df31_NMR

# %%
df34_NMR = df34
df34_NMR = df34_NMR.drop(df34_NMR.index[:187]) 
#df34_NMR

# %%
df24_NMR, df31_NMR, df34_NMR
# Out:
# (           DEPTH      CMFF      TCMR  CMRP_3MS
#  0    6037.897461  0.000066  0.025088  0.011304
#  1    6038.087891  0.000065  0.025079  0.011301
#  2    6038.278320  0.000065  0.025081  0.011301
#  3    6038.469238  0.000066  0.025086  0.011304
#  4    6038.659668  0.000066  0.025091  0.011306
#  ..           ...       ...       ...       ...
#  905  6210.299805  0.059779  0.103177  0.103177
#  906  6210.490723  0.059094  0.109203  0.106536
#  907  6210.681152  0.057959  0.108411  0.100711
#  908  6210.871582  0.058238  0.109660  0.098378
#  909  6211.062012  0.056559  0.114069  0.103018
#
#  [910 rows x 4 columns],
#              DEPTH      CMFF      TCMR  CMRP_3MS
#  280   6211.442871  0.121025  0.248994  0.243565
#  281   6211.633301  0.159654  0.280341  0.271579
#  282   6211.824219  0.186593  0.262605  0.246582
#  283   6212.014648  0.200451  0.233955  0.215445
#  284   6212.205078  0.163088  0.226603  0.210104
#  ...           ...       ...       ...       ...
# ...

# %%
df_NMR = pd.concat([df24_NMR, df31_NMR, df34_NMR], axis = 0, ignore_index = True)
df_NMR
# Out:
#             DEPTH      CMFF      TCMR  CMRP_3MS
# 0     6037.897461  0.000066  0.025088  0.011304
# 1     6038.087891  0.000065  0.025079  0.011301
# 2     6038.278320  0.000065  0.025081  0.011301
# 3     6038.469238  0.000066  0.025086  0.011304
# 4     6038.659668  0.000066  0.025091  0.011306
# ...           ...       ...       ...       ...
# 2643  6542.532227  0.004886  0.111587  0.042556
# 2644  6542.722656  0.005556  0.122516  0.045228
# 2645  6542.913086  0.006925  0.124411  0.050095
# 2646  6543.103516  0.009121  0.113042  0.046371
# 2647  6543.293945  0.006635  0.109188  0.041996
#
# [2648 rows x 4 columns]

# %% [markdown]
# # PLOT

# %%
fig, axes = plt.subplots(nrows=1, ncols=5, figsize=(12,14))
fig.suptitle("WELL : 3-EQNR-3-SPS", fontsize=15, fontweight='bold')
fig.subplots_adjust(top=0.75, wspace=0.5)

track_names = ['GR(gAPI)','AT10(ohm.m)','AT30(ohm.m)','AT90(ohm.m)','NPHI(m3/m3)','RHOZ(g/cm3)', 'PEFZ (B/E)','DTCO(us/ft)','NMREFF','NMRFF','NMRTOT']

#Set up the subplots grid
ax1 = plt.subplot2grid((1,5),(0,0),rowspan=1,colspan=1)    # GR  

ax2 = plt.subplot2grid((1,5),(0,1),rowspan=1,colspan=1)    # AT      
ax3 = ax2.twiny()
ax4 = ax2.twiny()

ax5 = plt.subplot2grid((1,5),(0,2),rowspan=1,colspan=1)    # RHOB
ax6 = ax5.twiny()                                          # NPHI
ax7 = ax5.twiny()                                          # PEFZ

ax8 = plt.subplot2grid((1,5),(0,3),rowspan=1,colspan=1)    # DTCO

ax9 = plt.subplot2grid((1,5),(0,4),rowspan=1,colspan=1)    # NMR
ax10 = ax9.twiny()
ax11 = ax9.twiny()


####################################################################


# First Track: GR
ax1.plot("GR","DEPTH", data = df_GR, color = "green", lw = 0.5)            # To call the data from the df dataframe 
ax1.set_xlim(0,120)                                                      
ax1.spines['top'].set_position(('outward',0)) 
ax1.set_xlabel('GR(gAPI)',color='green')  
ax1.set_ylabel('Measured Depth(m)',color='black') 
ax1.tick_params(axis='x', colors='green')
ax1.spines["top"].set_edgecolor("green")


# Second Track: RT90, RT30, AT10
ax2.plot("AT10","DEPTH", data= df_AT, color="black", lw = 0.5)
ax2.set_xlim(0.2,3000)                                                   # [0.2-2000] is the typical rang
ax2.semilogx()                                                           # x in a log scale
ax2.spines['top'].set_position(('outward',0))
ax2.set_xlabel('AT10(ohm.m)', color='black') 
ax2.tick_params(axis='x', colors='black')
ax2.spines["top"].set_edgecolor("black")

ax3.plot("AT30","DEPTH", data= df_AT, color="blue", lw = 0.5)
ax3.set_xlim(0.2,3000)                                                   # [0.2-2000] is the typical rang
ax3.semilogx()                                                           # x in a log scale
ax3.spines['top'].set_position(('outward',45))
ax3.set_xlabel('AT30(ohm.m)', color='blue') 
ax3.tick_params(axis='x', colors='blue')
ax3.spines["top"].set_edgecolor("blue")

ax4.plot("AT90","DEPTH", data= df_AT, color="red", lw = 0.5, linestyle = '--')
ax4.set_xlim(0.2,3000)                                                    
ax4.semilogx()                                                            
ax4.spines['top'].set_position(('outward',90))
ax4.set_xlabel('AT90(ohm.m)', color='red') 
ax4.tick_params(axis='x', colors='red')
ax4.spines["top"].set_edgecolor("red")


# Third Track: RHOZ, NPHI

ax5.plot("RHOZ","DEPTH", data= df_RHOZ, color="red", lw = 0.5)
ax5.set_xlim(1,4)
ax5.spines['top'].set_position(('outward',90))
ax5.set_xlabel('RHOZ(g/cm3)', color='red') 
ax5.tick_params(axis='x', colors='red')
ax5.spines["top"].set_edgecolor("red")


ax6.plot("NPHI","DEPTH", data= df_NPHI, color="blue", lw = 0.5, linestyle = '--')
ax6.set_xlim(0.45,-0.15)                                                         
ax6.spines['top'].set_position(('outward',45))
ax6.set_xlabel('NPHI(m3/m3)', color='blue') 
ax6.tick_params(axis='x', colors='blue')
ax6.spines["top"].set_edgecolor("blue")


# Forth Track: PEFZ
ax7.plot("PEFZ","DEPTH", data= df_PEFZ, color="darkorchid", lw = 0.5)
ax7.set_xlim(0,12)                                                      
ax7.spines['top'].set_position(('outward',0))
ax7.set_xlabel('PEFZ (B/E)', color='darkorchid') 
ax7.tick_params(axis='x', colors='darkorchid')
ax7.spines["top"].set_edgecolor("darkorchid")


# Fifth Track: DTCO
ax8.plot("DTCO","DEPTH", data= df_DTCO, color="blue", lw = 0.5)
ax8.set_xlim(100,0)                                                      
ax8.spines['top'].set_position(('outward',0))
ax8.set_xlabel('DTCO(us/ft)', color='blue') 
ax8.tick_params(axis='x', colors='blue')
ax8.spines["top"].set_edgecolor("blue")



# Sixth Track: NMR
ax9.plot("TCMR","DEPTH", data= df_NMR, color="darkred", lw = 0)
ax9.set_xlim(0.2,0)                                                   # [0.2-2000] is the typical rang   
ax9.spines['top'].set_position(('outward',90))
ax9.set_xlabel('NMRTOT', color='darkred') 
ax9.tick_params(axis='x', colors='darkred')
ax9.spines["top"].set_edgecolor("darkred")

ax10.plot("CMRP_3MS","DEPTH", data= df_NMR, color="olive", lw = 0)
ax10.set_xlim(0.2,0)                                                   # [0.2-2000] is the typical rang     
ax10.spines['top'].set_position(('outward',45))
ax10.set_xlabel('NMREFF', color='olive') 
ax10.tick_params(axis='x', colors='olive')
ax10.spines["top"].set_edgecolor("olive")

ax11.plot("CMFF","DEPTH", data= df_NMR, color="aqua", lw = 0)
ax11.set_xlim(0.2,0)                                                   # [0.2-2000] is the typical rang
ax11.spines['top'].set_position(('outward',0))
ax11.set_xlabel('NMRFF', color='aqua') 
ax11.tick_params(axis='x', colors='aqua')
ax11.spines["top"].set_edgecolor("aqua")

#======
import matplotlib.patches as mpatches

# Fill the areas with shading using RGB values and modified alpha values
ax9.fill_betweenx(df_NMR["DEPTH"], df_NMR["CMFF"], 0, facecolor=(0, 1, 1), alpha=0.8, interpolate=True)  # Aqua
ax9.fill_betweenx(df_NMR["DEPTH"], df_NMR["CMRP_3MS"], df_NMR["CMFF"], facecolor=(128/255, 128/255, 0), alpha=0.8, interpolate=True)  # Olive
ax9.fill_betweenx(df_NMR["DEPTH"], df_NMR["TCMR"], df_NMR["CMRP_3MS"], facecolor=(139/255, 0, 0), alpha=0.8, interpolate=True)  # Dark Red

# Create a legend for the fifth track
Clay_Bound_Water = mpatches.Patch(color=(139/255, 0, 0), label='CLAY BOUND WATER')
Bound_Water = mpatches.Patch(color=(128/255, 128/255, 0), label='BOUND WATER')
Free_Fluid = mpatches.Patch(color=(0, 1, 1), label='FREE FLUID')

legend = ax9.legend(handles=[Clay_Bound_Water, Bound_Water, Free_Fluid], loc='upper right', fontsize='xx-small', framealpha=0.7)

# Set the border properties of the legend
legend.get_frame().set_linewidth(2)
legend.get_frame().set_edgecolor('black')


###############################################################################################################################################################################

for i, ax in enumerate(fig.axes):
 
    ax.set_ylim(6600,6000)  # Set the depth range
                                          # Depth interval for the prediction
    
    ax.xaxis.set_ticks_position("top")
    ax.xaxis.set_label_position("top")
"""
    ax.set_xlabel(track_names[i])
    
    if i == 5:                                            
        ax.spines["top"].set_position(("axes", 2))
    else:
        ax.grid(color='black', lw=0.7)                  # To display the grid 
""" 

# Add a black border to each subplot 
for ax in [ax1, ax2, ax5, ax8, ax9]:
    ax.spines['bottom'].set_color('black')
    ax.spines['left'].set_color('black')
    ax.spines['right'].set_color('black') 

# Hide tick labels on the y-axis
for ax in [ax2, ax5, ax8, ax9]:
    plt.setp(ax.get_yticklabels(), visible=False)

    
# Reduce the space between each subplot
fig.subplots_adjust(wspace = 0.1)


###############################################################################################################################################################################
# Save plot

save_path = '/Users/amirhosseinakhondzadeh/CODE_WELLLOGS/Petrobras Well-log Analysis/Processed Data (out put of preprocessing == Input of ML)/Plots - data evaluation for selection/Well-log Plot (3-EQNR-3-SPS).png'

# Save the plot to the specified path
plt.savefig(save_path, dpi=300, bbox_inches="tight")

# Show the plot (optional)
plt.show()

# %% [markdown]
# # ================

# %% [markdown]
# <span style='color:brown'> <span style="font-size:19px;"> **STEP 5: create an unique DataFrame containing all the Well Log Data required for the ML prediction**

# %% [markdown]
# # 6050 - 6315 (RESERVOIR)

# %%
#=====
df23_GR = df23
df23_GR = df23_GR.drop(df23_GR.index[:517])  
df26_GR = df26
df26_GR = df26_GR.drop(df26_GR.index[:286])  
df_GR = pd.concat([df55_GR, df23_GR, df26_GR, df0_GR], axis = 0, ignore_index = True)

df12_NPHI = df12
df18_NPHI = df18  
df32_NPHI = df32
df18_NPHI = df18_NPHI.drop(df18_NPHI.index[:340])  
df32_NPHI = df32_NPHI.drop(df32_NPHI.index[:268]) 
df_NPHI = pd.concat([df12_NPHI, df18_NPHI, df32_NPHI], axis = 0, ignore_index = True)

df13_RHOZ = df13.drop(columns=["PEFZ"])
df19_RHOZ = df19.drop(columns=["PEFZ"])
df33_RHOZ = df33.drop(columns=["PEFZ"])
df19_RHOZ = df19_RHOZ.drop(df19_RHOZ.index[:880])  
df33_RHOZ = df33_RHOZ.drop(df33_RHOZ.index[:635])  
df_RHOZ = pd.concat([df13_RHOZ, df19_RHOZ, df33_RHOZ], axis = 0, ignore_index = True)

df13_PEFZ = df13.drop(columns=["RHOZ"])
df19_PEFZ = df19.drop(columns=["RHOZ"])
df33_PEFZ = df33.drop(columns=["RHOZ"])
df19_PEFZ = df19_PEFZ.drop(df19_PEFZ.index[:880])  
df33_PEFZ = df33_PEFZ.drop(df33_PEFZ.index[:635])  
df_PEFZ = pd.concat([df13_PEFZ, df19_PEFZ, df33_PEFZ], axis = 0, ignore_index = True)

df46_DTCO = df46
df49_DTCO = df49
df54_DTCO = df54
df49_DTCO = df49_DTCO.drop(df49_DTCO.index[:185]) 
df46_DTCO = df46_DTCO.drop(df46_DTCO.index[:400]) 
df_DTCO = pd.concat([df54_DTCO, df49_DTCO, df46_DTCO], axis = 0, ignore_index = True)

df1_AT = df1
df14_AT = df14
df20_AT = df20
df20_AT = df20_AT.drop(df20_AT.index[:644]) 
df1_AT = df1_AT.drop(df1_AT.index[:770]) 
df_AT = pd.concat([df14_AT, df20_AT, df1_AT], axis = 0, ignore_index = True)

df24_NMR = df24
df31_NMR = df31
df34_NMR = df34
df31_NMR = df31_NMR.drop(df31_NMR.index[:280]) 
df34_NMR = df34_NMR.drop(df34_NMR.index[:187]) 
df_NMR = pd.concat([df24_NMR, df31_NMR, df34_NMR], axis = 0, ignore_index = True)
#======

df_GR = df_GR[(df_GR.index >= 636) & (df_GR.index <= 2370)]
df_AT = df_AT[(df_AT.index >= 6370) & (df_AT.index <= 9840)]
df_RHOZ = df_RHOZ[(df_RHOZ.index >= 9560) & (df_RHOZ.index <= 14770)]
df_NPHI = df_NPHI[(df_NPHI.index >= 3185) & (df_NPHI.index <= 4920)]
df_DTCO = df_DTCO[(df_DTCO.index >= 265) & (df_DTCO.index <= 2002)]
df_PEFZ = df_PEFZ[(df_PEFZ.index >= 9560) & (df_PEFZ.index <= 14770)]
df_NMR = df_NMR[(df_NMR.index >= 67) & (df_NMR.index <= 1457)]

df_GR, df_AT, df_RHOZ, df_NPHI, df_DTCO, df_PEFZ, df_NMR
# Out:
# (            DEPTH         GR
#  636   6050.584961  27.374037
#  637   6050.737305  21.987434
#  638   6050.889648  28.754339
#  639   6051.041992  19.819307
#  640   6051.194336  38.248215
#  ...           ...        ...
#  2366  6314.693848  51.415714
#  2367  6314.846680  55.503613
#  2368  6314.999023  55.075043
#  2369  6315.151367  52.195042
#  2370  6315.303711  48.287144
#
#  [1735 rows x 2 columns],
#              DEPTH       AT10       AT20       AT30       AT60       AT90
#  6370  6050.432617  62.700562  82.297241  86.800438  73.769180  66.214760
#  6371  6050.508789  55.846077  66.352081  71.162857  62.146042  57.491840
#  6372  6050.584961  48.122364  54.185848  60.310467  52.081154  50.990688
#  6373  6050.661133  41.763863  45.644867  49.182899  44.655964  43.849117
#  6374  6050.737305  36.773373  39.721786  42.810596  39.704330  39.602875
#  ...           ...        ...        ...        ...        ...        ...
# ...

# %%
import pandas as pd

# Create a list of DataFrames to merge
dataframes_to_merge = [df_AT[['DEPTH', 'AT10', 'AT30', 'AT90']],
                       df_RHOZ[['DEPTH', 'RHOZ']],
                       df_NPHI[['DEPTH', 'NPHI']],
                       df_DTCO[['DEPTH', 'DTCO']],
                       df_PEFZ[['DEPTH', 'PEFZ']],
                       df_NMR[['DEPTH', 'CMFF', 'CMRP_3MS', 'TCMR']]]

# Initialize the merged DataFrame with df_GR
df_3_EQNR_3_ML = df_GR

# Loop through the list of DataFrames and merge them with df_944_ML
for df in dataframes_to_merge:
    df_3_EQNR_3_ML = pd.merge_asof(df_3_EQNR_3_ML, df, on='DEPTH', direction='nearest')

# Reset the index if needed
# df_944_ML.reset_index(drop=True, inplace=True)

# Display the merged DataFrame
df_3_EQNR_3_ML
# Out:
#             DEPTH         GR       AT10       AT30       AT90      RHOZ  \
# 0     6050.584961  27.374037  48.122364  60.310467  50.990688  2.300290
# 1     6050.737305  21.987434  36.773373  42.810596  39.602875  2.293669
# 2     6050.889648  28.754339  35.816006  40.594143  39.440018  2.217990
# 3     6051.041992  19.819307  39.945419  42.977238  45.657734  2.166148
# 4     6051.194336  38.248215  49.754284  59.098598  67.893845  2.218606
# ...           ...        ...        ...        ...        ...       ...
# 1730  6314.693848  51.415714   2.653257   2.131811   1.854116  2.507010
# 1731  6314.846680  55.503613   3.084166   2.306518   1.995265  2.487556
# 1732  6314.999023  55.075043   3.702130   2.748514   2.388380  2.476734
# 1733  6315.151367  52.195042   4.674475   3.237480   2.880047  2.480292
# 1734  6315.303711  48.287144   5.363100   3.552281   3.168717  2.502650
#
#           NPHI       DTCO      PEFZ      CMFF  CMRP_3MS      TCMR
# ...

# %% [markdown]
# We drop the NaN values. The new depth interval is

# %%
df_3_EQNR_3_ML = df_3_EQNR_3_ML.dropna()
df_3_EQNR_3_ML
# Out:
#             DEPTH         GR       AT10       AT30       AT90      RHOZ  \
# 0     6050.584961  27.374037  48.122364  60.310467  50.990688  2.300290
# 1     6050.737305  21.987434  36.773373  42.810596  39.602875  2.293669
# 2     6050.889648  28.754339  35.816006  40.594143  39.440018  2.217990
# 3     6051.041992  19.819307  39.945419  42.977238  45.657734  2.166148
# 4     6051.194336  38.248215  49.754284  59.098598  67.893845  2.218606
# ...           ...        ...        ...        ...        ...       ...
# 1730  6314.693848  51.415714   2.653257   2.131811   1.854116  2.507010
# 1731  6314.846680  55.503613   3.084166   2.306518   1.995265  2.487556
# 1732  6314.999023  55.075043   3.702130   2.748514   2.388380  2.476734
# 1733  6315.151367  52.195042   4.674475   3.237480   2.880047  2.480292
# 1734  6315.303711  48.287144   5.363100   3.552281   3.168717  2.502650
#
#           NPHI       DTCO      PEFZ      CMFF  CMRP_3MS      TCMR
# ...

# %% [markdown]
# Convert the DataFrame into a CSV file (CSV file is required for ML Algorithms implementation)

# %%
destination_file_path = '/Users/amirhosseinakhondzadeh/CODE_WELLLOGS/Petrobras Well-log Analysis/Processed Data (out put of preprocessing == Input of ML)/Output of well data, [unique dataframe creation]/df_3_EQNR_3_ML.csv'

df_3_EQNR_3_ML.to_csv(destination_file_path, index=None)

print(f"DataFrame saved as CSV file at: {destination_file_path}")
# Out:
# DataFrame saved as CSV file at: /Users/amirhosseinakhondzadeh/CODE_WELLLOGS/Petrobras Well-log Analysis/Processed Data (out put of preprocessing == Input of ML)/Output of well data, [unique dataframe creation]/df_3_EQNR_3_ML.csv
